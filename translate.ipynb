# %% [markdown]
# ### Translation task
# Europe is home to 24 official different languages. Although there are not many countries recognizing English as an official language, it is widely known that you can communicate in that language on most of the continent. Moreover, knowledge of English has become a necessity for those working in the IT industry and it represents the predominant language of communication in the technical domain as it facilitates global collaboration.
#
# Currently, our dataset combines multiple european languages across the samples obtained. Having English as the language of the dataset is ideal, and in this notebook we are going to, basically, detect the languages per row and, if the ad is not in english, we'll translate it to this language to ensure data consistency.
# The final dataset contains all job postings in English, allowing for uniform text analysis.
#
# ### Importing libraries

# %%
import pandas as pd
from langdetect import detect, DetectorFactory
from deep_translator import GoogleTranslator
import json
import os

# %% [markdown]
# ### Defining paths
# The described translation task is going to be performed per iteration, this will allow us to have a manageable amount of rows per iteration. This is why we'll use the "li_jobs.json" found in the data folder indicated, and the output will be in the folder of the corresponding iteration.

# %%
main_file="li_jobs.json"
output = "tr_li_jobs.json"
data_folder="data/7"
main_file_path = os.path.join(data_folder, main_file)
output_path = os.path.join(data_folder, output)

# %%
# Load the JSON file and check the number of rows
df_initial = pd.read_json(main_file_path)
row_count = df_initial.shape[0]
print(row_count)
# Out:
# 3944

# %%
# checking the first 10 rows of the dataframe
df_initial.head(10)
# Out:
#                                                Title  \
# 0  Délégué/Déléguée à la Protection des Données P...
# 1             NSI - Junior Security Engineer - FR/AN
# 2  Information Technology Support Specialist (m/f/d)
# 3        Data Protection & AI Compliance - Freelance
# 4                                           AI Tutor
# 5                     Network Security Administrator
# 6                           Administrative Assistant
# 7       Data Protection Specialist [m/w/d] / [m/f/d]
# 8                  Director of Sales - EMEA Overlay
# 9                     Threat Intelligence Consultant
#
#                                          Description  \
# 0  CFL multimodal regroupant les services transve...
# 1  Description de l'offre d'emploi\n\nAfin de ren...
# 2  About us \nAt RTL AdAlliance, we create simpli...
# 3  On E-Frontiers we're on the lookout for a Data...
# 4  The AI Tutor role is a remote, full-time, temp...
# 5  iKe recherche un consultant Network & Security...
# 6  AVEGA is a full-service provider based in the ...
# 7  Um unser Team am Standort Howald zu verstärken...
# 8  Director of Sales - EMEA Overlay Location: 100...
# 9  🔎 Now Hiring: Senior Cyber Threat Intelligence...
#
#                                  Primary Description  \
# 0  CFL - Société Nationale des Chemins de Fer Lux...
# 1  NSI Luxembourg PSF · Bertrange, Luxembourg, Lu...
# 2   RTL AdAlliance · Luxembourg, Luxembourg (Hybrid)
# 3              E-Frontiers · European Union (Remote)
# 4                                xAI · EMEA (Remote)
# 5   iKe Solutions · Luxembourg, Luxembourg (On-site)
# 6  AVEGA Luxembourg · Kirchberg, Luxembourg, Luxe...
# 7  Losch Luxembourg · Luxembourg, Luxembourg (On-...
# 8                           Hubscale · EMEA (Remote)
# 9    Stott and May · Luxembourg, Luxembourg (Hybrid)
#
#                                       Detail URL  \
# 0  https://www.linkedin.com/jobs/view/4221073209
# 1  https://www.linkedin.com/jobs/view/4235664393
# 2  https://www.linkedin.com/jobs/view/4232510933
# 3  https://www.linkedin.com/jobs/view/4221192811
# 4  https://www.linkedin.com/jobs/view/4198823312
# 5  https://www.linkedin.com/jobs/view/4239351140
# 6  https://www.linkedin.com/jobs/view/4216342656
# 7  https://www.linkedin.com/jobs/view/4228285731
# 8  https://www.linkedin.com/jobs/view/4233940752
# 9  https://www.linkedin.com/jobs/view/4218853949
#
#                             Location  \
# 0  Dudelange, Luxembourg, Luxembourg
# 1  Bertrange, Luxembourg, Luxembourg
# 2             Luxembourg, Luxembourg
# 3                     European Union
# 4                               EMEA
# 5             Luxembourg, Luxembourg
# 6  Kirchberg, Luxembourg, Luxembourg
# 7             Luxembourg, Luxembourg
# 8                               EMEA
# 9             Luxembourg, Luxembourg
#
#                                                Skill Insight Job State  \
# 0  Skills: General Data Protection Regulation (GD...            LISTED
# 1  Skills: Linux, Security Information and Event ...            LISTED
# 2         Skills: Windows 10, IT Operations, +8 more            LISTED
# 3  Skills: English, Artificial Intelligence (AI),...            LISTED
# 4  Skills: Analytical Skills, Professional Writin...            LISTED
# 5         Skills: Ticketing Systems, McAfee, +8 more            LISTED
# 6  Skills: Administrative Assistance, English, +8...            LISTED
# 7  Skills: Data Privacy, General Data Protection ...            LISTED
# 8          Skills: Overlay, Sales Processes, +8 more            LISTED
# 9  Skills: Security Information and Event Managem...            LISTED
#
#    Poster Id                                       Company Name  \
# 0  372922919  CFL - Société Nationale des Chemins de Fer Lux...
# 1  616927101                                 NSI Luxembourg PSF
# 2    9147426                                     RTL AdAlliance
# 3  339255538                                        E-Frontiers
# 4  664570951                                                xAI
# 5  409547717                                      iKe Solutions
# 6                                              AVEGA Luxembourg
# 7  473137745                                   Losch Luxembourg
# 8  636641157                                           Hubscale
# 9  172671873                                      Stott and May
#
#                                         Company Logo  \
# 0  https://media.licdn.com/dms/image/v2/D4E0BAQHE...
# 1  https://media.licdn.com/dms/image/v2/C4D0BAQH5...
# 2  https://media.licdn.com/dms/image/v2/D4E0BAQGo...
# 3  https://media.licdn.com/dms/image/v2/D4D0BAQFF...
# 4  https://media.licdn.com/dms/image/v2/D560BAQFG...
# 5  https://media.licdn.com/dms/image/v2/D4E0BAQHg...
# 6  https://media.licdn.com/dms/image/v2/C560BAQEg...
# 7  https://media.licdn.com/dms/image/v2/D4E0BAQFF...
# 8  https://media.licdn.com/dms/image/v2/D4E0BAQFK...
# 9  https://media.licdn.com/dms/image/v2/D4E0BAQEk...
#
#                  Created At                Scraped At
# 0  2025-05-02T11:04:25.000Z  2025-05-28T10:14:56.869Z
# 1  2025-05-27T13:19:58.000Z  2025-05-28T10:14:56.869Z
# 2  2025-05-21T12:50:10.000Z  2025-05-28T10:14:56.870Z
# 3  2025-05-05T09:40:19.000Z  2025-05-28T10:14:56.870Z
# 4  2025-04-03T17:31:51.000Z  2025-05-28T10:14:56.871Z
# 5  2025-05-28T08:57:57.000Z  2025-05-28T10:14:56.871Z
# 6  2025-04-24T09:29:50.000Z  2025-05-28T10:14:56.871Z
# 7  2025-05-12T11:29:55.000Z  2025-05-28T10:14:56.872Z
# 8  2025-05-23T16:33:00.000Z  2025-05-28T10:14:56.872Z
# 9  2025-04-30T17:00:39.000Z  2025-05-28T10:14:56.872Z

# %% [markdown]
# ### Translation Function
# Detects the language of specified columns and translates non-English text into English. It takes as parameters the DataFrame containing job listings, the number of rows to process and a boolean that indicates if keeping the original text in new columns for comparison is needed. This will be returning the modified DataFrame with translations in the desired columns.

# %%
DetectorFactory.seed = 0  # Ensures consistent language detection

# %%
def detect_and_translate(df, sample_size=row_count, show_original=False):
    # Columns to translate
    translate_cols = ['Title', 'Description', 'Primary Description', 'Specialties', 'Company Description']
    
    # Sample for validation
    sample_df = df.sample(n=sample_size, random_state=42).copy()

    def translate_text(text):
        # Detects language and translates to English, splitting if >5000 chars due to an API limitation.
        if pd.isna(text) or text.strip() == "":
            return text  # Skip empty or NaN values
        try:
            lang = detect(text)
            if lang != "en":
                if len(text) > 5000:
                    # Split into chunks under 5000 chars
                    chunks = []
                    start = 0
                    while start < len(text):
                        end = min(start + 4999, len(text))  # Max chunk size 4999
                        # Try to split at a natural boundary (period or space)
                        if end < len(text):
                            last_period = text.rfind('.', start, end)
                            last_space = text.rfind(' ', start, end)
                            split_point = max(last_period, last_space) if max(last_period, last_space) > start else end
                            end = split_point if split_point > start else end
                        chunks.append(text[start:end])
                        start = end + 1 if end < len(text) and text[end] in '. ' else end
                    # Translate each chunk and join
                    translated_chunks = []
                    for chunk in chunks:
                        if chunk.strip():  # Only translate non-empty chunks
                            translated_chunks.append(GoogleTranslator(source=lang, target="en").translate(chunk))
                        else:
                            translated_chunks.append(chunk)
                    return ' '.join(translated_chunks)
                else:
                    return GoogleTranslator(source=lang, target="en").translate(text)
        except Exception as e:
            print(f"Translation error: {e}")
            return text  # Return original text if translation fails
        return text  # Return original text if English

    # Apply translation function
    for col in translate_cols:
        if col in sample_df.columns:
            if show_original:
                # Store original text in a new column
                sample_df[f"{col}_original"] = sample_df[col]
            # Replace with translated text
            sample_df[col] = sample_df[col].apply(translate_text)

    return sample_df

# %% [markdown]
# ### Storing results
# Finally, the results are saved in the folder corresponding to the current iteration. A final merging for these translated versions per iteration is required to complete the dataset, and this can be performed in the last step of the merge-data.ipynb file.

# %%
translated_df = detect_and_translate(df_initial, sample_size=row_count, show_original=False)

translated_df = translated_df.to_dict(orient="records")
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(translated_df, f, ensure_ascii=False, indent=2)
# Out:
# Translation error: Senior Security DevOps Engineer
# 🏫: PPC Romania👥: Cyber Security📍: Bucuresti📝: Perioada nedeterminata
#
# #CarieraTa incepe cu a face ceea ce iti place 😊
#
# Suntem mereu in cautare de colegi talentati si motivati care sa ni se alature si, impreuna, sa contribuim la crearea unui viitor sustenabil, bazat pe incluziune, empatie, respect si egalitate de sanse.
#
# Iti cream contextul sa te dezvolti, fiind responsabil/a de:Definerea cerințelor și implementarea componentele de integrare și livrare legate de configurarea și validarea securității;Managementul infrastructurii AWS: Expertiză demonstrată în infrastructură ca serviciu (IaaS) pe AWS. Responsabil pentru proiectarea, implementarea și gestionarea resurselor AWS pentru a asigura performanța maximă, securitatea și optimizarea costurilor.Administrarea GitLab, asigurând configurarea, întreținerea și asistența optime, utilizându-l în același timp pentru controlul versiunilor și proiectarea și menținerea conductelor CI/CD robuste.Responsabil/a cu containerizare și orchestrare: Experiență practică vastă cu Docker și tehnologiile de containerizare. Experimentat în administrarea Kubernetes, inclusiv gestionarea clusterelor EKS, aplicațiilor containerizate și orchestrarea implementărilor la scară largă.Dezvoltarea și gestionarea infrastructure as code (IaC) folosind Terraform pentru a furniza și menține resursele în mod eficient.Utilizarea Ansible pentru a automatiza procesele de implementare și a eficientiza sarcinile de gestionare a configurației.Dezvoltarea de scripturi și instrumente în Python / Bash pentru automatizare și integrare.Configurare, monitorizarea și alertarea folosind Prometheus pentru colectarea măsurătorilor.Creearea tablourilor de de bord și vizualizarea datelelor cu Grafana.Implementarea, agregărea și analiza jurnalelor cu Loki.Colaboarea cu echipele interfuncționale pentru a asigura implementarea și funcționarea fără probleme a sistemelor.Efectuarea de troubleshoot în vederea rezolvării problemelor de infrastructură / aplicații în timp util.Informarea în mod proactiv cu privire la cele mai recente tendințe, instrumente și cele mai bune practici DevOps si securitatea informatiei.Dar vei si participa în procesele de „release” și în activitățile de tip „on-call” asociate cu procesele de „release” sau alte activități interne și externe de audit ale securității;
#
# Dorim sa te alaturi in calatoria noastra cu: Cunoștințe avansate de securitate în cloudExpertiză vastă în proiectarea, implementarea și gestionarea serviciilor în AWS, împreună cu o înțelegere profundă a conceptelor de cloud computing.Containerizare și orchestrare: Docker, K8s.Competență în GitLab, Terraform, Ansible, Python, Bash, Prometheus, Grafana și Loki.Înțelegere puternică a conductelor CI/CD, automatizării și infrastructurii ca cod.Managementul secretelor: HashiCorp Vault, AWS Secret ManagerExperiență de lucru cu telemetria de securitate și soluțiile de tip SIEMCu abilitatea de a îndruma și ghida membrii juniori ai echipei, încurajând dezvoltarea abilităților și promovând cele mai bune practici în cadrul echipei.Abilități excelente de comunicare;Abilitatea de conduce discuții despre proiectare, de a oferi soluții la incidentele apărute și de a interacționa cu membrii conducerii;Abilitatea de a soluționa problemele, deficiențele și de a identifica informațiile relevante în reportarea unui defect;Abilitatea de a comunica informații tehnice, atât în scris cât și verbal, într-o manieră care să fie înțeleasă de toate părțile interesante (dezvoltare, proiectare, management);Experiență de lucru în cadrul unui mediu cooperant, orientat spre echipă;Atenție excepțională la detalii.
#
# Vino in echipa #PPC si te asteptam cu:
#
# ✔️ Perspective de evolutie in carieraoportunitati de dezvoltare profesionala si personalamediu de lucru dinamic si linii de business diversificatemediu de lucru internationalprograme de mobilitate internacursuri, sesiuni de coaching, mentorat
#
# 💸 RecompenseAbonament medical/asigurare medicalaTichete de masa, prime (Ziua Energeticianului, Paste, Craciun etc)Al 13 lea salariuDecontarea unei parti din biletul de concediuZile de concediu suplimentar in functie de vechimea in muncaZile libere extra (Ziua de nastere, Ziua Energeticianului etc)Oferte speciale din partea colaboratorilor nostriProgram de bonusare a recomandarilor de noi angajatiAbonament Bookster
#
#
# 💻Mod de lucruMod de lucru hybrid (birou & smartworking)Short Friday
#
#
#
# Ce altceva trebuie sa stii
# Confidențialitatea procesului de recrutareLa PPC, respectăm confidențialitatea fiecărei aplicații. Doar candidații selectați vor fi contactați pentru interviu, iar celelalte candidaturi vor fi păstrate în baza noastră de date timp de maximum un an.
# Despre PPCSuntem lideri în energie în Europa de Sud-Est, activi în producția, distribuția și furnizarea de energie electrică, dar și în dezvoltarea de soluții inovatoare pentru un viitor sustenabil. Cu o capacitate instalată de 10,7 GW, furnizăm energie pentru 8,7 milioane de clienți și --> No translation was found using the current translator. Try another translator?
# Translation error: Request exception can happen due to an api connection error. Please check your connection and try again
# Translation error: Request exception can happen due to an api connection error. Please check your connection and try again
# Translation error: Munich Re · Valletta, Valletta, Malta (Hybrid) --> No translation was found using the current translator. Try another translator?
# Translation error: Cast AI · Bulgaria (Remote) --> No translation was found using the current translator. Try another translator?
