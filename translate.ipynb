# %% [markdown]
# ### Translation task
# Europe is home to 24 official different languages. Although there are not many countries recognizing English as an official language, it is widely known that you can communicate in that language on most of the continent. Moreover, knowledge of English has become a necessity for those working in the IT industry and it represents the predominant language of communication in the technical domain as it facilitates global collaboration.
#
# Currently, our dataset combines multiple european languages across the samples obtained. Having English as the language of the dataset is ideal, and in this notebook we are going to, basically, detect the languages per row and, if the ad is not in english, we'll translate it to this language to ensure data consistency.
# The final dataset contains all job postings in English, allowing for uniform text analysis.
#
# ### Importing libraries

# %%
import pandas as pd
from langdetect import detect, DetectorFactory
from deep_translator import GoogleTranslator
import json
import os

# %% [markdown]
# ### Defining paths
# The described translation task is going to be performed per iteration, this will allow us to have a manageable amount of rows per iteration. This is why we'll use the "li_jobs.json" found in the data folder indicated, and the output will be in the folder of the corresponding iteration.

# %%
main_file="li_jobs.json"
output = "tr_li_jobs.json"
data_folder="data/6"
main_file_path = os.path.join(data_folder, main_file)
output_path = os.path.join(data_folder, output)

# %%
# Load the JSON file and check the number of rows
df_initial = pd.read_json(main_file_path)
row_count = df_initial.shape[0]
print(row_count)
# Out:
# 7182

# %%
# checking the first 10 rows of the dataframe
df_initial.head(10)
# Out:
#                                           Title  \
# 0                         Vulnerability Analyst
# 1                                   Helpdesk IT
# 2                 Cyber Security Analyst, Italy
# 3                           NOC Engineer Junior
# 4  2025 Security Specialist Intern, DC Security
# 5              Cyber Defense Center SOC Analyst
# 6                         Cybersecurity Analyst
# 7             Cybersecurity Junior - Automotive
# 8              Junior Risk & Compliance Analyst
# 9                                   SOC Analyst
#
#                                          Description  \
# 0  Vulnerability Analyst Junior\nAlfa Group è una...
# 1  Anemocyte, Biotech Manufacturing Organization ...
# 2  The IT/Cyber Security Analyst is a global role...
# 3  In iliad, abbiamo rivoluzionato il mercato del...
# 4  Description\n\nAWS is growing rapidly, and we ...
# 5  Con oltre 1.000 specialisti IT presenti in 6 P...
# 6  Cybersecurity Analyst con esperienza nella ges...
# 7  🟠🔵Teoresi S.p.A. , 35+ anni di storia , 6 soci...
# 8  Rad è alla ricerca di un Junior Security Consu...
# 9  Per conto di prestigioso cliente in ambito Cyb...
#
#                                  Primary Description  \
# 0          Alfa Group · Rome, Latium, Italy (Hybrid)
# 1  ANEMOCYTE  · Gerenzano, Lombardy, Italy (On-site)
# 2               ION · Pisa, Tuscany, Italy (On-site)
# 3           iliad · Milan, Lombardy, Italy (On-site)
# 4  Amazon Web Services (AWS) · Milan, Lombardy, I...
# 5    Würth Phoenix · Milan, Lombardy, Italy (Hybrid)
# 6      agap2 Italia · Verona, Veneto, Italy (Hybrid)
# 7   Teoresi Group · Turin, Piedmont, Italy (On-site)
# 8  RAD Cyber Security · Greater Milan Metropolita...
# 9  Azienda Riservata Italia · Emilia-Romagna, Ita...
#
#                                       Detail URL  \
# 0  https://www.linkedin.com/jobs/view/4233218439
# 1  https://www.linkedin.com/jobs/view/4224479861
# 2  https://www.linkedin.com/jobs/view/4023610804
# 3  https://www.linkedin.com/jobs/view/4230031910
# 4  https://www.linkedin.com/jobs/view/4188426286
# 5  https://www.linkedin.com/jobs/view/4233626307
# 6  https://www.linkedin.com/jobs/view/4225641811
# 7  https://www.linkedin.com/jobs/view/4195446112
# 8  https://www.linkedin.com/jobs/view/4221531535
# 9  https://www.linkedin.com/jobs/view/4233005171
#
#                           Location  \
# 0              Rome, Latium, Italy
# 1       Gerenzano, Lombardy, Italy
# 2             Pisa, Tuscany, Italy
# 3           Milan, Lombardy, Italy
# 4           Milan, Lombardy, Italy
# 5           Milan, Lombardy, Italy
# 6            Verona, Veneto, Italy
# 7           Turin, Piedmont, Italy
# 8  Greater Milan Metropolitan Area
# 9            Emilia-Romagna, Italy
#
#                                                Skill Insight Job State  \
# 0              Skills: Python (Programming Language)            LISTED
# 1  Skills: Troubleshooting, Computer Repair, +8 more            LISTED
# 2  Skills: Linux, Security Information and Event ...            LISTED
# 3  Skills: Network Operations Center (NOC), Troub...            LISTED
# 4  Skills: Security Operations, Criminology, +8 more            LISTED
# 5  Skills: Security Operations, Tracking Systems,...            LISTED
# 6  Skills: Computer Network Operations, Security ...            LISTED
# 7  Skills: CAN bus, Internet of Things (IoT), +3 ...            LISTED
# 8  Skills: KYC Verification, Anti-Money Launderin...            LISTED
# 9  Skills: Security Operations, System on a Chip ...            LISTED
#
#     Poster Id               Company Name  \
# 0   974757775                 Alfa Group
# 1   122533242                 ANEMOCYTE
# 2    79075618                        ION
# 3   984227560                      iliad
# 4   355872060  Amazon Web Services (AWS)
# 5   416073494              Würth Phoenix
# 6  1221573374               agap2 Italia
# 7   662759130              Teoresi Group
# 8   632403450         RAD Cyber Security
# 9   629194346   Azienda Riservata Italia
#
#                                         Company Logo  \
# 0  https://media.licdn.com/dms/image/v2/D4D0BAQFF...
# 1  https://media.licdn.com/dms/image/v2/D4D0BAQEm...
# 2  https://media.licdn.com/dms/image/v2/D4E0BAQEj...
# 3  https://media.licdn.com/dms/image/v2/D4D0BAQHV...
# 4  https://media.licdn.com/dms/image/v2/D4E0BAQE0...
# 5  https://media.licdn.com/dms/image/v2/C4E0BAQFR...
# 6  https://media.licdn.com/dms/image/v2/C4D0BAQHs...
# 7  https://media.licdn.com/dms/image/v2/D4D0BAQFO...
# 8  https://media.licdn.com/dms/image/v2/C4D0BAQFD...
# 9
#
#                  Created At                Scraped At
# 0  2025-05-22T12:38:10.000Z  2025-05-22T12:46:03.839Z
# 1  2025-05-09T12:31:14.000Z  2025-05-22T12:46:03.840Z
# 2  2024-09-11T17:18:24.000Z  2025-05-22T12:46:03.841Z
# 3  2025-05-14T15:50:52.000Z  2025-05-22T12:46:03.842Z
# 4  2025-03-18T21:13:12.000Z  2025-05-22T12:46:03.842Z
# 5  2025-05-20T14:47:18.000Z  2025-05-22T12:46:03.843Z
# 6  2025-05-12T09:33:41.000Z  2025-05-22T12:46:03.844Z
# 7  2025-03-31T09:10:18.000Z  2025-05-22T12:46:03.844Z
# 8  2025-05-05T15:28:03.000Z  2025-05-22T12:46:03.845Z
# 9  2025-05-22T12:33:19.000Z  2025-05-22T12:46:03.846Z

# %% [markdown]
# ### Translation Function
# Detects the language of specified columns and translates non-English text into English. It takes as parameters the DataFrame containing job listings, the number of rows to process and a boolean that indicates if keeping the original text in new columns for comparison is needed. This will be returning the modified DataFrame with translations in the desired columns.

# %%
DetectorFactory.seed = 0  # Ensures consistent language detection

# %%
def detect_and_translate(df, sample_size=row_count, show_original=False):
    # Columns to translate
    translate_cols = ['Title', 'Description', 'Primary Description', 'Specialties', 'Company Description']
    
    # Sample for validation
    sample_df = df.sample(n=sample_size, random_state=42).copy()

    def translate_text(text):
        # Detects language and translates to English, splitting if >5000 chars due to an API limitation.
        if pd.isna(text) or text.strip() == "":
            return text  # Skip empty or NaN values
        try:
            lang = detect(text)
            if lang != "en":
                if len(text) > 5000:
                    # Split into chunks under 5000 chars
                    chunks = []
                    start = 0
                    while start < len(text):
                        end = min(start + 4999, len(text))  # Max chunk size 4999
                        # Try to split at a natural boundary (period or space)
                        if end < len(text):
                            last_period = text.rfind('.', start, end)
                            last_space = text.rfind(' ', start, end)
                            split_point = max(last_period, last_space) if max(last_period, last_space) > start else end
                            end = split_point if split_point > start else end
                        chunks.append(text[start:end])
                        start = end + 1 if end < len(text) and text[end] in '. ' else end
                    # Translate each chunk and join
                    translated_chunks = []
                    for chunk in chunks:
                        if chunk.strip():  # Only translate non-empty chunks
                            translated_chunks.append(GoogleTranslator(source=lang, target="en").translate(chunk))
                        else:
                            translated_chunks.append(chunk)
                    return ' '.join(translated_chunks)
                else:
                    return GoogleTranslator(source=lang, target="en").translate(text)
        except Exception as e:
            print(f"Translation error: {e}")
            return text  # Return original text if translation fails
        return text  # Return original text if English

    # Apply translation function
    for col in translate_cols:
        if col in sample_df.columns:
            if show_original:
                # Store original text in a new column
                sample_df[f"{col}_original"] = sample_df[col]
            # Replace with translated text
            sample_df[col] = sample_df[col].apply(translate_text)

    return sample_df

# %% [markdown]
# ### Storing results
# Finally, the results are saved in the folder corresponding to the current iteration. A final merging for these translated versions per iteration is required to complete the dataset, and this can be performed in the last step of the merge-data.ipynb file.

# %%
translated_df = detect_and_translate(df_initial, sample_size=row_count, show_original=False)

translated_df = translated_df.to_dict(orient="records")
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(translated_df, f, ensure_ascii=False, indent=2)
# Out:
# Translation error: Consultant  art.1 l.68/99 (categoria protetta) --> No translation was found using the current translator. Try another translator?
# Translation error: zh-cn --> No support for the provided language.
# Please select on of the supported languages:
# {'afrikaans': 'af', 'albanian': 'sq', 'amharic': 'am', 'arabic': 'ar', 'armenian': 'hy', 'assamese': 'as', 'aymara': 'ay', 'azerbaijani': 'az', 'bambara': 'bm', 'basque': 'eu', 'belarusian': 'be', 'bengali': 'bn', 'bhojpuri': 'bho', 'bosnian': 'bs', 'bulgarian': 'bg', 'catalan': 'ca', 'cebuano': 'ceb', 'chichewa': 'ny', 'chinese (simplified)': 'zh-CN', 'chinese (traditional)': 'zh-TW', 'corsican': 'co', 'croatian': 'hr', 'czech': 'cs', 'danish': 'da', 'dhivehi': 'dv', 'dogri': 'doi', 'dutch': 'nl', 'english': 'en', 'esperanto': 'eo', 'estonian': 'et', 'ewe': 'ee', 'filipino': 'tl', 'finnish': 'fi', 'french': 'fr', 'frisian': 'fy', 'galician': 'gl', 'georgian': 'ka', 'german': 'de', 'greek': 'el', 'guarani': 'gn', 'gujarati': 'gu', 'haitian creole': 'ht', 'hausa': 'ha', 'hawaiian': 'haw', 'hebrew': 'iw', 'hindi': 'hi', 'hmong': 'hmn', 'hungarian': 'hu', 'icelandic': 'is', 'igbo': 'ig', 'ilocano': 'ilo', 'indonesian': 'id', 'irish': 'ga', 'italian': 'it', 'japanese': 'ja', 'javanese': 'jw', 'kannada': 'kn', 'kazakh': 'kk', 'khmer': 'km', 'kinyarwanda': 'rw', 'konkani': 'gom', 'korean': 'ko', 'krio': 'kri', 'kurdish (kurmanji)': 'ku', 'kurdish (sorani)': 'ckb', 'kyrgyz': 'ky', 'lao': 'lo', 'latin': 'la', 'latvian': 'lv', 'lingala': 'ln', 'lithuanian': 'lt', 'luganda': 'lg', 'luxembourgish': 'lb', 'macedonian': 'mk', 'maithili': 'mai', 'malagasy': 'mg', 'malay': 'ms', 'malayalam': 'ml', 'maltese': 'mt', 'maori': 'mi', 'marathi': 'mr', 'meiteilon (manipuri)': 'mni-Mtei', 'mizo': 'lus', 'mongolian': 'mn', 'myanmar': 'my', 'nepali': 'ne', 'norwegian': 'no', 'odia (oriya)': 'or', 'oromo': 'om', 'pashto': 'ps', 'persian': 'fa', 'polish': 'pl', 'portuguese': 'pt', 'punjabi': 'pa', 'quechua': 'qu', 'romanian': 'ro', 'russian': 'ru', 'samoan': 'sm', 'sanskrit': 'sa', 'scots gaelic': 'gd', 'sepedi': 'nso', 'serbian': 'sr', 'sesotho': 'st', 'shona': 'sn', 'sindhi': 'sd', 'sinhala': 'si', 'slovak': 'sk', 'slovenian': 'sl', 'somali': 'so', 'spanish': 'es', 'sundanese': 'su', 'swahili': 'sw', 'swedish': 'sv', 'tajik': 'tg', 'tamil': 'ta', 'tatar': 'tt', 'telugu': 'te', 'thai': 'th', 'tigrinya': 'ti', 'tsonga': 'ts', 'turkish': 'tr', 'turkmen': 'tk', 'twi': 'ak', 'ukrainian': 'uk', 'urdu': 'ur', 'uyghur': 'ug', 'uzbek': 'uz', 'vietnamese': 'vi', 'welsh': 'cy', 'xhosa': 'xh', 'yiddish': 'yi', 'yoruba': 'yo', 'zulu': 'zu'}
# Translation error: Offre d’emploi : Architecte Cybersécurité (H/F)
# 📍 Localisation : Île-de-France (Paris ou proche banlieue)🕓 Expérience requise : Minimum 7 ans🎓 Niveau d'études : Bac +5 (École d’ingénieurs, Master cybersécurité, réseaux, ou informatique)🗣️ Langue : Anglais professionnel requis📅 Type de contrat : CDI
# Leader mondial de l’Ingénierie et du Conseil en Technologies, ALTEN réalise des projets de conception et d’études pour les grands comptes industriels, télécoms et tertiaires (les Directions Techniques et les Directions des Systèmes d’Information).Désormais présent à travers 30 pays, le Groupe ALTEN a réalisé un chiffre d’affaires de 4,07 milliards d’euros en 2023 et compte actuellement 57 000 collaborateurs, dont 90% sont des ingénieurs.Labélisé "Top employeur" 2023, ALTEN est un acteur majeur du recrutement d’ingénieurs en France et dans le monde.
# Description du poste :
# Contexte :Dans un contexte de renforcement des enjeux liés à la sécurité des systèmes d'information, nous recherchons un Architecte Cybersécurité pour accompagner nos clients grands comptes dans la conception, la validation et la sécurisation de leurs architectures IT et Cloud.Vous serez un acteur clé dans la stratégie de cybersécurité, en interaction directe avec les équipes architecture, IT, cloud, réseau, conformité, et les RSSI.
# Missions principales :🛡️ Conception & Architecture SécuriséeDéfinir des architectures sécurisées (on-premise, cloud, hybride) en conformité avec les standards du marché (ISO 27001, NIST, ANSSI, CIS).Réaliser des études de risques (EBIOS, MEHARI ou équivalent) et proposer des plans de remédiation adaptés.Intégrer les exigences de sécurité dans les projets IT et métiers dès la phase de cadrage.🔐 Sécurité des Infrastructures et CloudDéfinir et déployer des architectures de sécurité pour les environnements Cloud (AWS, Azure, GCP), notamment les solutions de chiffrement, IAM, bastion, gestion des logs et audit.Contribuer à la sécurisation des flux réseau, des accès à privilèges (PAM), et des systèmes d’authentification (SSO, MFA).Accompagner les équipes projets dans le respect du “Security by Design” et des politiques de sécurité internes.🧰 Gouvernance, Conformité et Politique de SécuritéÉlaborer et maintenir les cadres d’architecture sécurité, les standards techniques et les modèles de sécurité.Participer à l’évaluation de la conformité réglementaire (RGPD, LPM, DORA, etc.).Collaborer avec les DPO, RSSI et équipes juridiques pour assurer la conformité des solutions aux exigences légales.🧪 Analyse, Audit et RésilienceRéaliser des revues d’architecture, des analyses de sécurité, des contrôles techniques et des tests de conformité.Participer aux audits de sécurité (internes et externes).Accompagner la mise en place de solutions de détection d’incidents (SIEM, EDR) et de réponse (SOC, SOAR, plan de reprise d'activité, PRA/PCA).📚 Veille technologique et supportMaintenir une veille active sur les menaces, vulnérabilités et innovations technologiques.Être un référent sécurité auprès des équipes internes et des clients.Préparer des supports de sensibilisation, former les équipes techniques, et contribuer à la culture cybersécurité globale.
# Environnement technique à connaître :🔐 Sécurité Systèmes & Réseaux :Concepts de segmentation réseau, zones de confiance, pare-feu nouvelle génération (NGFW), VPN, proxy, WAF, NAC.Outils : Fortinet, Palo Alto, Check Point, Cisco ASA, F5 BIG-IP.☁️ Sécurité Cloud :Maîtrise des services natifs de sécurité :AWS (IAM, KMS, CloudTrail, GuardDuty, Security Hub)Azure (Defender, Key Vault, Azure Policy, Sentinel)GCP (Cloud IAM, Security Command Center, KMS)🛠️ Outils de sécurité & supervision :SIEM : Splunk, QRadar, Sentinel, Elastic SIEMEDR : CrowdStrike, SentinelOne, Microsoft Defender for EndpointVulnerability Management : Qualys, Nessus, TenableSOAR : TheHive, Cortex XSOAR🗝️ IAM & Contrôle d’accès :RBAC, ABAC, MFA, SAML, OAuth2, OpenID Connect, AD/LDAPSolutions : Okta, CyberArk, Ping Identity, Azure AD🛡️ Outils d’analyse et durcissement :CIS Benchmarks, Lynis, OpenSCAP, SCAP WorkbenchAnalyse de logs, forensic de sécurité, sandboxing (Cuckoo, FireEye)⚙️ Méthodes & Référentiels :ISO 27001/27005, NIST, EBIOS RM, OWASP, MITRE ATT&CKFramework DevSecOps, Zero Trust Architecture
#
# Qualifications: Profil recherché :Bac +5 en informatique, cybersécurité ou réseaux (école d’ingénieurs ou master).Minimum 7 ans d’expérience dans la sécurité des systèmes d'information ou l’architecture.Solide compréhension des menaces, vulnérabilités, et techniques de mitigation.Expérience dans des environnements complexes et multi-cloud.Excellente communication écrite et orale, en français comme en anglais professionnel.Esprit d’analyse, rigueur, sens du conseil et leadership technique.
#
# Les + du poste :Participation à des projets à forte criticité (secteurs finance, énergie, santé, etc.)Environnement stimulant avec un haut niveau d'expertise en sécurité.Parcours de certification soutenu (CISSP, CISM, CCSP, ISO 27001 Lead --> No translation was found using the current translator. Try another translator?
# Translation error: Assistant(e) Product Manager en Alternance - Startup Studio CybersécuritéType de contrat : Apprentissage / Contrat de professionnalisation Durée : 12 mois Début souhaité : Septembre 2025 Lieu : Lyon Rémunération : Selon grille légale en vigueur et profil Rattachement hiérarchique : Vous travaillerez en étroite collaboration avec le CEO & co-fondateur, Laurent Hausermann, et serez mentoré(e) par l'équipe Produit et le CTO.
#
# 🌍 L'Aventure CyGO-Entrepreneurs
# CyGO-Entrepreneurs est une aventure entrepreneuriale née en mars 2024 avec une mission claire: faire émerger les futurs champions européens de la cybersécurité. Dans un monde où les lignes entre numérique et géopolitique s'entremêlent chaque jour un peu plus, la cybersécurité n’est plus un sujet de spécialistes. C’est un enjeu de société, une clé pour protéger nos libertés, notre économie, nos données… et parfois même nos vies. Chez CyGO-Entrepreneurs, on croit que l’innovation peut ET doit jouer un rôle décisif. On construit des start-ups à fort impact avec une ambition: faire de l’Europe un acteur majeur de la cybersécurité.
# 🕵️‍♀️ / 🕵️‍♂️ Notre Mission chez CyGO-Entrepreneurs ?
#  Créer un futur numérique plus sûr, plus libre, plus européen!Concrètement, ça veut dire quoi ?On accompagne des entrepreneurs ambitieux pour qu’ils imaginent et construisent des solutions de cybersécurité innovantes, utiles et impactantes.Pour les aider à aller vite ET loin, on s’appuie sur Le Club by CyGO : une communauté active d’experts, de partenaires et d’investisseurs prêts à partager leur savoir-faire.Parce qu’on est convaincus que l’Europe a un rôle clé à jouer dans ce combat, on œuvre chaque jour à renforcer son autonomie technologique et son autonomie numérique.
# C’est là qu’on a besoin de vous ❗️CyGO-Entrepreneurs, c’est un collectif d’entrepreneurs passionnés qui lancent des startups en cybersécurité. Entourés de fondateurs expérimentés (business et tech – nos "Entrepreneurs In Residence") et soutenus par des investisseurs européens, nous construisons les futures pépites tech du secteur. Et aujourd’hui, on cherche un(e) alternant(e) de l’énergie, de la curiosité et de l’envie pour nous aider à faire émerger les prochains projets qui changeront la donne !
#  Aucune semaine ne se ressemble!
# 💼 Vos missions : apprendre, explorer, construire (et recommencer)
# Vous accompagnerez l’équipe dans l’exploration des opportunités, la structuration des idées et le lancement des premiers MVP.Vous collaborerez au quotidien avec les fondateurs, la core team (CTO, UX, marketing) et nos Entrepreneurs-in-Residence.
#  Le profil que nous recherchons:Vous êtes étudiant(e) en Master (Bac+5/6) au sein d'une Grande École de Management ou d’Ingénieur, avec une spécialisation en Entrepreneuriat, Innovation, Management de Projet, Stratégie ou Digital.Une passion communicative pour le Product Management et l'univers effervescent des startups technologiques (SaaS, Cloud, IA, IoT, Data... si ces mots vous parlent, on est sur la bonne voie!).Une première expérience (stage, projet étudiant significatif) dans un environnement startup serait un plus.Une curiosité insatiable pour les nouvelles technologies et une vraie motivation pour les défis de la cybersécurité (vous avez envie de contribuer à protéger nos entreprises, renforcer la souveraineté européenne et soutenir des innovations qui comptent).Vous possédez de bonnes capacités d'analyse, de synthèse et de résolution de problèmes.Vous êtes proactif(ve), organisé(e), à prendre les choses en main et à aimer apprendre en faisant.L'UX (expérience utilisateur) et le Design, ça vous parle : vous pensez que la forme est aussi importante que le fond.Vous êtes toujours prêt(e) à aider et à construire ensemble.Excellent niveau de français et d'anglais (lu, écrit, parlé), vous évoluerez dans un contexte international.Le petit + qui fait la différence : Vous avez déjà monté un projet (même le stand de crêpes de votre promo, si c'était épique !), participé à des hackathons ou des concours d'innovation ? Racontez-nous !
# 👀 Pourquoi faire votre alternance chez CyGO-Entrepreneurs?
# Un impact qui dépasse la tech Ici, chaque ligne de code, chaque user story, chaque idée contribue à quelque chose de plus grand : renforcer la sécurité et la liberté numériques en Europe. Vous ne serez pas un rouage : vous serez un bâtisseur.Un vrai terrain d’entraînement pour apprendre en faisant. Vous serez au cœur de l’action : plusieurs produits à imaginer, tester, lancer. C’est une occasion rare d’explorer le métier de Product Manager dans toute sa richesse – stratégie produit, user research, prototypage, delivery…Une immersion en conditions réelles de lancement de start-up. Chez CyGO-Entrepreneurs, on va vite, on vise haut, et on apprend tout le temps. Vous évoluerez dans une équipe passionnée, curieuse, qui cultive la rigueur autant que la créativité.Un écosystème stimulant Workshops, masterclass, rencontres avec des experts, accès privilégié à un réseau unique dans la cybersécurité : --> No translation was found using the current translator. Try another translator?
# Translation error: zh-cn --> No support for the provided language.
# Please select on of the supported languages:
# {'afrikaans': 'af', 'albanian': 'sq', 'amharic': 'am', 'arabic': 'ar', 'armenian': 'hy', 'assamese': 'as', 'aymara': 'ay', 'azerbaijani': 'az', 'bambara': 'bm', 'basque': 'eu', 'belarusian': 'be', 'bengali': 'bn', 'bhojpuri': 'bho', 'bosnian': 'bs', 'bulgarian': 'bg', 'catalan': 'ca', 'cebuano': 'ceb', 'chichewa': 'ny', 'chinese (simplified)': 'zh-CN', 'chinese (traditional)': 'zh-TW', 'corsican': 'co', 'croatian': 'hr', 'czech': 'cs', 'danish': 'da', 'dhivehi': 'dv', 'dogri': 'doi', 'dutch': 'nl', 'english': 'en', 'esperanto': 'eo', 'estonian': 'et', 'ewe': 'ee', 'filipino': 'tl', 'finnish': 'fi', 'french': 'fr', 'frisian': 'fy', 'galician': 'gl', 'georgian': 'ka', 'german': 'de', 'greek': 'el', 'guarani': 'gn', 'gujarati': 'gu', 'haitian creole': 'ht', 'hausa': 'ha', 'hawaiian': 'haw', 'hebrew': 'iw', 'hindi': 'hi', 'hmong': 'hmn', 'hungarian': 'hu', 'icelandic': 'is', 'igbo': 'ig', 'ilocano': 'ilo', 'indonesian': 'id', 'irish': 'ga', 'italian': 'it', 'japanese': 'ja', 'javanese': 'jw', 'kannada': 'kn', 'kazakh': 'kk', 'khmer': 'km', 'kinyarwanda': 'rw', 'konkani': 'gom', 'korean': 'ko', 'krio': 'kri', 'kurdish (kurmanji)': 'ku', 'kurdish (sorani)': 'ckb', 'kyrgyz': 'ky', 'lao': 'lo', 'latin': 'la', 'latvian': 'lv', 'lingala': 'ln', 'lithuanian': 'lt', 'luganda': 'lg', 'luxembourgish': 'lb', 'macedonian': 'mk', 'maithili': 'mai', 'malagasy': 'mg', 'malay': 'ms', 'malayalam': 'ml', 'maltese': 'mt', 'maori': 'mi', 'marathi': 'mr', 'meiteilon (manipuri)': 'mni-Mtei', 'mizo': 'lus', 'mongolian': 'mn', 'myanmar': 'my', 'nepali': 'ne', 'norwegian': 'no', 'odia (oriya)': 'or', 'oromo': 'om', 'pashto': 'ps', 'persian': 'fa', 'polish': 'pl', 'portuguese': 'pt', 'punjabi': 'pa', 'quechua': 'qu', 'romanian': 'ro', 'russian': 'ru', 'samoan': 'sm', 'sanskrit': 'sa', 'scots gaelic': 'gd', 'sepedi': 'nso', 'serbian': 'sr', 'sesotho': 'st', 'shona': 'sn', 'sindhi': 'sd', 'sinhala': 'si', 'slovak': 'sk', 'slovenian': 'sl', 'somali': 'so', 'spanish': 'es', 'sundanese': 'su', 'swahili': 'sw', 'swedish': 'sv', 'tajik': 'tg', 'tamil': 'ta', 'tatar': 'tt', 'telugu': 'te', 'thai': 'th', 'tigrinya': 'ti', 'tsonga': 'ts', 'turkish': 'tr', 'turkmen': 'tk', 'twi': 'ak', 'ukrainian': 'uk', 'urdu': 'ur', 'uyghur': 'ug', 'uzbek': 'uz', 'vietnamese': 'vi', 'welsh': 'cy', 'xhosa': 'xh', 'yiddish': 'yi', 'yoruba': 'yo', 'zulu': 'zu'}
# Translation error: Nous recherchons un Analyste GRC pour accompagner un de nos clients dans l'évaluation, la gestion et la mise en œuvre de stratégies de conformité et de gestion des risques.
# 🚀 Parlons de votre missionAu sein de Synchrone, société de conseil leader de la transformation digitale, vous avez la charge de faire valoir votre expertise pour nos clients grands comptes.Sur les différents environnements de nos clients vous êtes amené à réaliser différentes tâches :Concevoir, formaliser et maintenir des politiques et des procédures pour la gestion des risques, la gouvernance d'entreprise, ainsi que la conformité réglementaire (ISO, RGPD, etc.).Mettre en place des cadres de gouvernance adaptés à chaque client, en prenant en compte la structure organisationnelle, les risques identifiés et les exigences spécifiques du secteur.Effectuer des évaluations approfondies des risquesUtiliser des outils et des techniques d'évaluation des risques (RiskWatch, RSA Archer, etc.) pour identifier les risques opérationnels, technologiques, financiers et réglementaires.Proposer des actions correctives et des plans d'atténuation détaillés pour minimiser les risques tout en optimisant les processus métier.Assurer la conformité avec les réglementations locales, nationales et internationales (par exemple : ISO 27001, SOX, GDPR, FCPA, etc.), en effectuant des audits réguliers et des tests de conformité.Fournir des conseils pratiques sur la mise en œuvre de la conformité, en utilisant des outils de gestion de la conformité tels que OneTrust, ComplyAdvantage, ou des systèmes internes de gestion des politiques.Participer à des projets de mise en conformité avec les standards de sécurité des informations (par exemple, SOC 2, PCI-DSS).Définir et mettre en œuvre des contrôles internes efficaces pour surveiller les risques et garantir la conformité continue.Effectuer des tests réguliers de l'efficacité des contrôles de sécurité (tests de pénétration, simulations d'attaque, tests de conformité des systèmes de gestion de la sécurité de l'information).Collaborer avec les équipes internes et externes pour évaluer et tester la résilience des contrôles face aux menaces émergentes.
# 💪 Parlons de vousDiplôme en gestion des risques, en droit, en cybersécurité, ou dans un domaine connexe.Minimum de 3 à 5 ans d'expérience dans un rôle similaire, avec une expertise dans la mise en œuvre de solutions GRC pour des clients externesExcellentes aptitudes à la gestion de projets et à la coordination interdisciplinaire.Autonomie, capacité d’analyse, sens des responsabilités et forte capacité à travailler sous pression
# Certifications appréciées :ISO 27001 Lead Implementer ou Lead AuditorCISA (Certified Information Systems Auditor)CRISC (Certified in Risk and Information Systems Control)CISM (Certified Information Security Manager) ou toute autre certification pertinente.
# 💻 Parlons de vos compétencesPour vous épanouir sur ce poste, vous êtes à l’aise dans les environnements suivants :Expertise en ISO 27001, ISO 9001, ISO 31000, SOC 2, PCI-DSS, RGPD, CCPA, HIPAA, et autres régulations spécifiques à la sécurité et à la protection des données.NIST Cybersecurity Framework (CSF)ISO 22301 (Gestion de la continuité des affaires)ISO 27002 (Code de pratique pour la gestion de la sécurité de l'information)DORAExpérience avec des outils comme RSA Archer, MetricStream, OneTrust, ComplyAdvantage, ainsi que des outils d’audit comme Nessus et Burp Suite pour l’analyse de sécuritéCompétences en analyse des vulnérabilités, évaluation des menaces dans un environnement hybride, et utilisation d’outils d'analyse quantitativeExpérience dans la mise en place de systèmes ISMS
# 💥 Pourquoi nous ?Au cœur de la transformation digitale et de la tech, Synchrone - 1600 collaborateurs - accompagne ses clients, grands groupes français et internationaux, sur des missions à forte valeur ajoutée en consulting bancaire et financier, cybersécurité et sécurité des réseaux, stratégie et projets digitaux, infracloud, web/mobile et applicatif, data, etc.Nos secteurs de prédilection : Luxe, Banque/Assurance, Retail, Transport, Média & Télécoms, Energie & Environnement, Internet & Software, Industrie & Services.ESN engagée, inclusive et handi-accueillante, Synchrone recrute et reconnait tous les talents !Rejoindre Synchrone, c’est faire partie d’une société qui privilégie la co-construction et le bien-être de ses salariés. Vous évoluez au sein d’un modèle à taille humaine et devenez un acteur clé du développement de votre société.💼 Carrière et accompagnement | Management de proximité et suivi RH dédié, programme de développement de compétences💯 INPULSE 2 | Projets transverses (recrutement, formation, AO, référent sur site, cooptation, apport d’affaires) rétribués par des primes🏅 United Heroes x Synchrone | Programme sport & bien-être : challenges, coaching, webinaires (...) via une app dédiée et récompenses toute l’année🌎 RSE | Engagement QVCT (organisation de travail mixte, équilibre pro/perso, diversité…) et --> No translation was found using the current translator. Try another translator?
# Translation error: REJOIGNEZ UN COLLECTIF ANIME PAR LE GOUT DU DEFI
#
# Rejoignez Peaksys, la filiale Tech de Cnova, et façonnez l’avenir du e-commerce à grande échelle !
#
# Chez #Peaksys, plus de 600 experts passionnés conçoivent et opèrent des solutions digitales à l’échelle pour tout l’écosystème Cnova (Cdiscount, Octopia, C-Logistics, CnovaPay).
#
# Notre terrain de jeu ?  1 milliard de recherches moteur par an, jusqu’à 1200 commandes par minute lors du Black Friday et un déploiement en production toutes les 7 minutes.
#
# Notre mission : accélérer le business en livrant rapidement des fonctionnalités à forte valeur ajoutée, alliant excellence produit et alignement avec les besoins métiers.
#
# Envie de relever des défis d’envergure ? Rejoignez Peaksys et prenez part à une aventure humaine et technologique hors norme.
#
# EXPLOREZ UN CHAMP DES POSSIBLES SANS ÉQUIVALENCE
#
# Rejoignez Peaksys, venez faire du hors norme votre norme.
#
# Intégré en tant qu’Expert en Développement Sécurisé et rattaché à la Direction Cybersécurité, vous jouerez un rôle clé dans la conception, la revue la mise en œuvre de pratiques de développement en intégrant les standards de sécurité du domaine.
#
# Vous Assurerez Les Missions Suivantes
#
# Conseiller et accompagner les équipes produit dans l’intégration de la sécurité, dès les phases de conception – by design et tout au long du cycle de vie des livrables – by default,Prendre en main le parcours de formation SecureCoding et former les équipes, Revoir les architectures techniques pour optimiser leur robustesse,Evaluer et administrer les outils et processus de tests de sécurité, et leur intégration dans les pipelines de déploiementContribuer à la mise en place de mesures liées au niveau de sécurité du code source de l’entreprise,Participer à la veille des menaces émergentes touchant nos technologies utilisées avec vos collègues de la DSSI,Mener des campagnes gamifiées en interne, de type CTF par exemple.
#
# SEREZ-VOUS “THE ONE”💥?
#
# Votre Domaine Technique
#
#  OWASP Top 10 / ASVS / SAMM et MITRE NIST SSDF (SP 800-53 / SP 800-218), Microsoft SDL ISO 27001 / 27002 Threat Modeling, SAST (Checkmarx / Trivy), DAST, SCA, code review, …. CI/CD / Azure Devops / Kubernetes / Docker C#, ASP.Net MVC, Python, OpenID/REST
#
# Nous recherchons des collaborateurs ayant une énergie hors pair pour prendre part à une aventure humaine et professionnelle unique.
#
# Issu d'une école d'ingénieur ou universitaire avec une spécialisation en informatique, vous justifiez d'au minimum de 5 ans d'expérience en développement sécurisé en cabinet de conseil ou chez un client final.
#
# Vous avez déjà réalisé des audits de sécurité de code et mis en œuvre des processus de sensibilisation / formation en toute autonomie. Votre implication dans le domaine de la sécurité informatique et de la veille technique de manière plus générale, via vos projets personnels ou vos participations à différents évènements et/ou publications (CTFs, conférences, blogging, bug hunting, bulletins de vulnérabilités, développement personnel (repos git/lab/hub)), est un plus.
#
# Doté d'une bonne capacité d'analyse, d'un bon relationnel et d'une grande capacité à comprendre la criticité des applications, vous savez être force de proposition auprès des équipes. Vous avez de bonnes compétences rédactionnelles en français comme en anglais.
#
# Autonome et rigoureux dans la réalisation de votre travail, vous possédez une forte expertise, démontrez de bonnes aptitudes pédagogiques, et êtes ouvert d'esprit sur les nouvelles technologies.
#
# Fort de vos expériences et de vos connaissances techniques, vous aimez transmettre votre savoir et vos connaissances et souhaitez proposer vos idées et être force de proposition afin d’améliorer le quotidien des équipes.
#
# Peaksys est un employeur investi en faveur de la diversité : du recrutement à l'évolution professionnelle, nous garantissons l'égalité des chances à tous nos collaborateurs.
#
# Vous êtes persuadé que l’avenir appartient à celles et ceux qui osent faire bouger les lignes ? Nous aussi. Alors, Inventez-tout, Révélez-vous !
#
# Venez développer vos compétences et votre employabilité dans un environnement de travail unique :
#
# 🏡 : Un accord télétravail pouvant aller jusqu’à 2 jours par semaine,
#
# 🌉 : Des locaux modernes et situés au bord de la Garonne en plein cœur des Bassins à Flots, hub de la tech Bordelaise,
#
# 🎤 : Des animations, conférences, et temps d’échanges dédiés avec la Direction,
#
# 🎓 : Une offre de formation innovante et à la pointe des nouvelles technologies,
#
# 🏆 : De nombreux labels obtenus (Great Place To Work, Happy Trainees, AFNOR "Diversité" et "Egalité F/H"),
#
# 🛒 : Avantages exclusifs Cdiscount,
#
# 🎢 : Des offres avantageuses grâce au CSE (cinéma, parcs de loisirs, concerts),
#
# 🌍 : L’opportunité d’être acteur d’initiatives RSE et liées à la Diversité : (HandiTeam, GreenTeam),
#
# 👶🏽 : Des places en crèches et un dispositif de garde d’enfant en urgence,
#
# 💰 : Des plans d'épargnes (PEE, PERCOL, abondement employeur sur versements volontaires),
#
# Et Les --> No translation was found using the current translator. Try another translator?
# Translation error: Rejoignez l’aventure ArianeGroup et participez à la conquête de l’innovation spatiale ! 🚀
#
# 🌍 Votre environnement de travail
#
# Intégré(e) au sein du service Industrial Systems Automatization qui assure la spécification, la conception, la réalisation (grâce à son laboratoire) et le MCO des systèmes spécifiques automatisés, robotisés, de contrôle commande et supervision industriels des moyens sols sur les différents sites et programmes de la société civils ou militaires.
#
# Au sein de cette équipe, L’ingénieur(e) mécatronique et contrôle commande est à la convergence de nombreuses spécialités : électrotechnique, électronique, mécanique, software, automatisme et fluidifie les échanges entre les différents métiers.
#
# Vous serez également l'expert(e) en spécification, conception, construction, gestion et maintenance de systèmes "mécaniques" contenant des éléments électriques et électroniques contrôlés par des systèmes informatiques, principalement des machines spéciales et solutions d'automatisme industrielles.
#
# 🔍 Vos missions
#
# En tant qu’Ingénieur(e) Mécatronique et Contrôle Commande, vous serez responsable d'activités automatisme, contrôle commande et supervision sur les programmes cités précédemment en phase d'avant-projet, de développement ou de MCO.
#
# Vos principales activités en tant qu'Ingénieur(e) mécatronique et Contrôle Commande seront les suivantes :
#
# Réaliser des études, analyses techniques et les chiffrerConception et/ou spécification de systèmes automatisés et robotisés, des IHM (Interface Homme Machine), d’API process ou de sécurité. Conception et réalisation de l’architecture multi-système, réalisation des synoptiques, analyse de la conformité à l’environnement de travailRéaliser le suivi technique de l’exécution du projet/produit ou de la fabrication du produit en atelier ou en sous-traitanceRecherche et mise en place des plans d’essais, conception/spécification des outillages nécessairesRéalisation de démonstrateurs au sein du Lab AutomRédaction de documentation pour les projets (STB, CDC, notes techniques, expertises, documentation de communication de projet), mise en place de l’organisation d’un projet, gestion des prestationsParticiper aux revues de projets aux jalons clés (validation de la conception par exemple)Standardisation des outils "d'informatique Industrielle" (Outils de supervision, de simulation...)Modélisation CAO Electrique, Mécanique et RobotiqueAssumer la fonction d'expertise dans les domaines Electrotechnique, Contrôles Commande, Supervision et Robotique. Prise en charge des études amonts d'évaluation de nouveaux systèmes d'exploitation, langages et librairies. Intégrer les moyens développés/rénovés sur les différents sitesParticiper à la phase de test unitaire et d'intégration de nos équipements électroniques, automatismes et robotique afin d'intégrer des nouvelles technologiesRéaliser des avants projetsPlanifier les études et les réalisations et assurer le respect du délai de réalisation, ainsi que la conformité technique et réglementaire. Recherche de solutions techniques innovantes pour les projets (Veille technologique, essais...)Vous contribuerez également à l’amélioration des processus de l’activité (rédaction de fiche de RETEX par exemple) et à la préparation du futur (Veille techno, sourcing, benchmark, visite de salons...).
#
# 🎯 Profil recherché
#
# 🎓 Formation : Bac+5 (Ingénieur ou équivalent), idéalement spécialisée en Automatismes Industriels, Informatique Industriel, Electrotechnique, Mécatronique ou Robotique.
#
# Expérience d’au moins 8 ans dans un environnement industriel
#
# Vous avez eu des expériences en bureau d'études de moyens industriels et dans la conduite / gestion de projets industriels
#
# Connaissances en systèmes automatisés :
#
# Conception électrique et mécanique, automatisme, robotique, électrotechnique, cybersécurité, informatique industrielle et réseaux.
#
# Contrôle commande et conduite de projets industriels.
#
# Compétences en pilotage et suivi sur la mise en œuvre d'un projet :
#
# Définir la faisabilité et la rentabilité du projet en s'appuyant sur les équipes pluridisciplinaires
#
# Gérer le suivi financier de projets complexes
#
# S'assurer des conditions optimales pour l'industrialisation et la production du projet
#
# Connaissance et exploitation des outils numériques appropriés (Suite Microsoft Office, Confluence, Ubikey, Planisware, PLM-T...)
#
# Compétences en rédaction de documentation technique
#
# Veiller au respect des normes et règles sécuritaires
#
# 🌍 Anglais courant (lecture, rédaction et échanges techniques)
#
# 👩‍🚀👨‍🚀 Qualités personnelles :
#
# Vous avez une avez un fort esprit d'équipe, des capacités d'adaptation et d'agilité ainsi que de ténacitéVous faites preuve d’ouverture d’esprit, d'honnêteté, de coopération, de rigueurVous êtes reconnu(e) pour votre sens du service, vos qualités de communication et de pédagogie, d'esprit d'analyse et de synthèseVous possédez des connaissances et une certaine passion pour les domaines du Spatiale & de la Défense
#
# 💼 Informations --> No translation was found using the current translator. Try another translator?
# Translation error: 📍 Localisation : 18 Av. Edouard Belin, 31400 Toulouse (CNES)📄 Contrat : CDI, statut cadre🕒 Horaires : Horaires administratifs avec astreintes pour assurer la continuité de service✈️ Déplacements : Déplacements ponctuels à l’étranger possibles
# Vous souhaitez rejoindre un environnement spatial exigeant, au sein d’une équipe dynamique et engagée ?
# Rattaché(e) à l’équipe Sécurité SAR Galileo de Telespazio France, vous contribuez au maintien en conditions opérationnelles des systèmes sol dédiés au service de recherche et sauvetage par satellites (SAR Galileo). Cette équipe de 5 à 10 personnes fait partie d’un groupe composé d’une trentaine de collaborateurs impliqués dans l’exploitation et l’ingénierie des systèmes SAR Galileo et Cospas-Sarsat.
#  En lien étroit avec les équipes d’exploitation, d’ingénierie et les partenaires institutionnels (CNES, Commission européenne…), vous assurez la sécurité des infrastructures critiques dans un cadre réglementaire exigeant.
# 🛰️ Vos principales missions seront :
# Administrer les fonctions de sécurité des segments sol SAR Galileo et produire les comptes-rendus associésÉlaborer, valider, mettre à jour et archiver les procédures et les scripts liés à la sécuritéContrôler régulièrement l’état de sécurité des composants du système et produire les rapports correspondantsMaintenir les tableaux de bord, modèles de reporting et procédures de surveillanceProposer et documenter des solutions de contournement en cas d’anomalie, tout en assurant la traçabilité des actionsParticiper aux réunions de suivi des anomalies et assurer un lien étroit avec les équipes d’ingénierie et d’opérationsSuivre et qualifier les évolutions techniques impactant la sécurité, et mettre à jour les supports associésParticiper à la rédaction des rapports de validation de sécuritéContribuer à la mise à jour du plan de formation sécurité de l’équipeAssurer un reporting régulier de votre activité auprès des responsablesInteragir avec le CNES lors de réunions de coordination et veiller à la satisfaction client sur le périmètre confié
#
# 🎯 Profil recherché :
# Vous êtes diplômé(e) d’un Bac+5 (école d’ingénieur ou master universitaire) avec une spécialisation en cybersécurité ou en informatique, et vous justifiez d’une première expérience d’au moins 2 ans dans le domaine de la cybersécurité, idéalement dans un environnement sensible ou réglementé (spatial, aéronautique, défense, etc.).
# Vous maîtrisez les fondamentaux de la cybersécurité et disposez d’une expertise dans au moins un des domaines suivants :
# Durcissement des systèmes, gestion des accès (MAC, ACL),Détection de vulnérabilités, veille CERT,Supervision de la sécurité (SIEM, SOC),Réseaux sécurisés (firewall, routage, IDS/NDS),Gestion des identités (IAM, LDAP).
# Vous êtes également à l’aise avec :
# L’administration de systèmes UNIX/Linux et Windows,Le scripting Shell ou Python,Les protocoles et algorithmes cryptographiques,Les normes de sécurité (ISO 27001, EBIOS RM, GDPR, NIS2, etc.),Les architectures segment sol spatiales ou aéronautiques.Un très bon niveau d’anglais est indispensable (C1 écrit et oral).
# Concernant les qualités personnelles, vous vous distinguez par :
# Votre rigueur et votre sens des responsabilitésVotre discrétion et votre respect des règles de confidentialitéVotre capacité à travailler efficacement en équipeVotre aisance à communiquer de manière claire et structuréeVotre autonomie et votre sens de l’organisationVotre esprit de synthèse et votre capacité à prioriserVotre réactivité et votre fiabilité en environnement opérationnel
# Avantages :
# Épargne salariale : PEE et PERECOPrimes sur objectif, d’intéressement et de participationRTT et Compte Épargne Temps (CET)Une mutuelle prenant en charge votre famille Avantages culturels et sportifs via le comité d’entreprise (billetterie, hébergement, transports…)Télétravail (2 jours par semaine après la phase d'intégration réussie, si le projet le permet)
# Si cette opportunité vous intéresse et si vous avez pris le temps de parcourir ces informations, postulez dès à présent !
# Description de l'entreprise :
# Telespazio France est une entreprise leader dans le domaine dans les opérations spatiales et des services satellitaires à valeur ajoutée. Nous offrons des solutions innovantes et des technologies de pointe dans les domaines historiques mais aussi émergents du secteur spatial comme la surveillance de l'espace, les services en orbite ou les micro lanceurs.
# Fort de ses 500 collaborateurs qui sont la plus grande richesse de Telespazio France, l'entreprise s'organise autour de 2 domaines d'excellence, appelés Line of Business (LoB) :
# * LoB Space Systems & Operations qui commercialise et fournit des services pour les opérations satellitaires ;* LoB Services qui regroupe les services à valeur ajoutée dans les télécommunications, l'observation de la Terre et la navigation;
# Implanté dans les villes françaises les plus emblématiques de la filière spatiale que sont Toulouse, Bordeaux, Paris et Kourou (Guyane Française), --> No translation was found using the current translator. Try another translator?
# Translation error: Envie d'un nouveau challenge professionnel ? Ça tombe bien, votre mission (si vous l'acceptez) se trouve ici 👇🏻
# Chez Conserto Toulouse, on ne recrute pas juste des CV, on cherche des talents qui carburent à la créativité, au café ☕(thé, chocolat chaud c'est ok aussi !), et au plaisir de bosser en équipe ! Venez écrire la suite avec nous (spoiler alert : ça risque d’être passionnant).
# Notre expertise gravite autour de l'Infra, du DevOps, du Digital et de l'Agilité au sein de PME et de Grands Comptes.
# Je vous propose de rejoindre notre agence Toulousaine composée de : Nicolas, notre Directeur d'agence, inconditionnel du Coca Zéro au petit déjeune et cycliste aguerri 🚵🏻‍♂️Hassan, notre Ingénieur d'affaires en alternanceLaurie, notre Chargée de Développement RHMalivanh, Chargée de recrutement (celle qui vous parle actuellement), amoureuse du sucre sous toutes ses formes (surtout les pâtisseries 🧁)Elodie, notre Assistante d'agence, dopée au café ☕et au running 🏃🏻‍♀️‍➡️Et surtout ! Nos 30 Consertiens passionnés !
#
# Notre histoire 📖
# Créé en 2013 à Nantes, Conserto est une ESN (Entreprise de Services Numériques) portant haut les valeurs de la collaboration, de la prise d’initiatives et de l’évolution de ses 479 collaborateurs 🙌
# Nous intervenons chez nos clients sur 5 pôles d'expertises :Infra (réseau, sécurité, système, virtualisation, cybersécurité)DevOps (Terraform, Kubernetes, Ansible, Docker, GitLabCI...)Développement (Java / Angular ...)Culture agile (Scrum, SaFe, Kanban...)Numérique responsable (accessibilité, éco-conception)
# Pourquoi nous choisir ? 🤗
# 🌞 Le bien-être ainsi que le développement professionnel de nos collaborateurs sont notre priorité, un Consertien heureux est un client heureux.
# ✅ Nous visons toujours la qualité : des profils recrutés, de votre relation avec vos clients, du suivi de vos collaborateurs, etc. Nous faisons en sorte d’augmenter chaque année la satisfaction de nos Consertiens, qui est déjà de plus de 90% en 2024.
# 👩🏽‍🤝‍👩🏻 Concrètement, chaque agence dispose aujourd’hui d’un(e) chargé(e) de carrière et fidélisation pour réaliser un suivi RH sur-mesure. Ils pilotent également la formation de nos collaborateurs, dont 63% ont été formés en 2023.Chaque collaborateur bénéficie d'un accompagnement personnalisé avec une Roadmap claire et des comités de carrières trimestriels pour suivre leur progrès et identifier de nouvelles opportunités.
# 🌳 En dernier, pour rejoindre une ESN à la pointe de l’écologie (certification RSE Lucie et Ecovadis). Je vous invite à aller jeter un coup d’œil à notre projet primé Green Trackr, car oui, nous avons aussi pour ambition de rendre le monde meilleur.
#
# Le job que l’on vous propose : 🔍
# Nous vous voyons venir : "Oh non, encore une annonce générique….". Le descriptif vous paraitra peut-être générique car notre objectif est d’échanger de vive voix. Selon vos aspirations, nous serons plus à même de vous présenter les missions et environnements de travail susceptibles de vous correspondre parmi la diversité de nos clients toulousains  avec lesquels nous travaillons.Les enjeux ? Sécurisation de leur SI, mise en place d'une démarche devOps, move to cloud…
# En tant qu'INGENIEUR SECURITE ET RESEAU N3 (H/F), vous serez amené(e) à:
# Concevoir et mettre en œuvre de nouvelles architectures réseauConfigurer et administrer les équipements réseau : switch, routeurs, firewalls, VPN Load balancers...Optimiser les performances réseauSurveiller les infrastructuresGérer la sécurité des systèmes : gestion des firewalls et des systèmes de détection/prévention d'intrusion, gérer les accès d'authentificationConseiller et implémenter les demandes d’évolutionRésoudre les problèmes complexesAnalyser de manière approfondie les logs et les diagnostics réseauAssurer le Build et le Run N3.…
# Les compétences minimales attendues pour le poste : 👀
# Nous ne recherchons pas le mouton à 5 pattes mais en priorité quelqu’un de passionné, qui a 4 ans d’expérience minimum, qui a de l'autonomie sur certains des outils phares (pour les autres, nous vous accompagnerons) :Réseau : VPN, LAN/WAN, routage, switches (nexus, arista, Cisco ACI…), F5 BigIPFirewall : Fortinet, Checkpoint, Stormshield, Palo alto…Proxy : Broadcom, McAfeeProtocoles : BGP, MPLS-VPN (MP-BGP), OSPF, IPv4, IPv6, FlexVPN (DMVPN), OTV, DSCP, SNMP, Netflow
# Vous ne cochez pas toutes les cases ? Pas de panique, c'est un éventail d'environnement technique que vous pourrez croiser chez nos clients.
# Votre personnalité 👤
# Parce que chez nous l'attitude compte autant que les compétences ! Vous êtes:Dynamique et inspirante(e) : Votre énergie ⚡ est contagieuse, vous savez insuffler une belle ambiance et faire bouger les choses, que ce soit pour nos clients ou au sein de l'agence.Orienté(e) service et satisfaction client : Vous avez à cœur d’offrir une expérience mémorable et de grande qualité, en apportant de la vraie valeur ajoutée, des solutions pertinentes à chaque projet.Esprit de conseil : Avec un œil averti, toujours à l’écoute et attentif(ve) aux --> No translation was found using the current translator. Try another translator?
# Translation error: 🟠🔵Teoresi S.p.A. , 35+ anni di storia , 6 società tra Italia, Stati Uniti, Germania, Svizzera, +1200 risorse, 3 acquisizioni in un anno, 1 solo partner ed un’unica soluzione.🔵🟠
# Per ampliamento di un Team dedicato a progetti interni in diversi settori di mercato (Automazione Industriale - Energia - Automotive - Ferroviario - Oil & Gas - Difesa), è alla ricerca di un/una:
# CYBERSECURITY ENGINEER – EMBEDDED SYSTEMS
# Il/la candidat* ideale ha conseguito la Laurea in informatica, sicurezza informatica (o affini) e ha maturato almeno 3 anni di esperienza nello sviluppo di funzionalità di sicurezza su sistemi embedded e safety-critical.
# La persona sarà responsabile dell'identificazione delle cyber threats, della definizione di strategie di mitigazione e della garanzia di conformità agli standard internazionali di cybersecurity come IEC 62443, ISO/SAE 21434 o EN 50701.Collaborerà strettamente con architetti di sistema, sviluppatori e safety teams per integrare la cybersecurity lungo tutto il ciclo di vita delle piattaforme.
# COSA FARAI:
# Definizione e identificazione dei trust boundariesEseguire cyber risk assessments, threat modeling e vulnerability analysis su ECU veicolari e reti embeddedSupportare l’implementazione dei principi di Security-by-DesignDefinire e mantenere i requisiti e le architetture di cybersecurityGuidare o supportare audit di sicurezza, penetration testing e revisioni del codiceAssicurare la conformità agli standard di cybersecurity (es. IEC 62443, ISO/SAE 21434, EN 50701, CRA)Supportare funzionalità come secure boot, implementazioni crittografiche e protocolli di comunicazione sicuraInterfacciarsi con stakeholder di progetto, fornitori ed enti certificatori su tematiche di sicurezza
# 🖥️LE SKILL TECNICHE:
# Solida conoscenza della sicurezza di rete, protocolli sicuri e crittografiaCompetenza nel secure coding (C/C++) e conoscenza dei protocolli CAN, LIN o EthernetBuona conoscenza di normative come IEC 62443, EN 50701 o ISO 27001Eccellenti capacità analitiche ed esperienza in threat modeling e penetration testingEsperienza pregressa nello sviluppo software embeddedLa familiarità con normative e standard del settore automotive (es. AUTOSAR, ISO 26262, ISO 21434, UNECE R155, UNECE R156) e il possesso di Certificazioni come CISSP, CEH o credenziali specifiche per il settore (es. formazione ISO 21434) rappresentano un plusGradita l'esperienza con aggiornamenti over-the-air (OTA) e sviluppo firmware sicuro
# 👁️ OCCHIO: È richiesta ottima conoscenza della lingua inglese, poiché il candidato ideale verrà inserito in un team internazionale!
# 🔝COMPLETANO IL PROFILO:
# - Spiccata attitudine al lavoro in team e propensione alla leadership- Spiccate doti relazionali- Elevata capacità di problem solving
# 📍Sede di lavoro: Torino, Modena, Napoli, Roma, Bari.
# ➡️ Qual è il prossimo step?
# Potresti essere contattato dal nostro team HR per approfondire le tue competenze e i tuoi interessi, in modo da considerare il tuo profilo per ogni posizione aperta in linea con il tuo profilo.
# 🔎Cosa offriamo?
# · Contratto full time, tempo indeterminato CCNL Metalmeccanico· Modalità di lavoro flessibile· Ticket Restaurant del valore di EURO 8.· Assicurazione Sanitaria e Welfare previsti da CCNL di Riferimento
# 🟠🔵Perché scegliere Teoresi?
# Teoresi è una realtà nata a Torino e cresciuta fino a diventare oggi un gruppo internazionale, che si propone ovunque si respiri innovazione. Perseguiamo l’aggiornamento continuo rispetto all’evoluzione tecnologica, collaborando con aziende Leader in diversi settori di mercato e realizzando soluzioni “chiavi in mano” presso i nostri laboratori.
# Lavoriamo mantenendo al centro le persone e la sostenibilità ambientale.Crediamo nel risultato generato dall’unione del talento creativo e la solida preparazione dei nostri collaboratori, strumenti vincenti per rendere la tecnologia un ponte verso il cambiamento e proporre soluzioni che siano “un passo avanti”, anticipando bisogni e tendenze future a beneficio della vita umana.
# 🫂 Amiamo le occasioni di incontro, per questo supportiamo eventi in grado di generare nuove opportunità, non solo di business, ma anche di scambio culturale, intergenerazionale, internazionale, riducendo qualsiasi distanza. Scopri di più sul Connection Day, l’evento aziendale che ogni anno ci porta a conoscerci e ritrovarci! https://www.teoresigroup.com/it/connect/experiences/
# 🌳 Nel welcome kit troverai una borraccia in acciaio brandizzata realizzata da 24 Bottles, nata dall’idea di sostituire i distributori automatici di bottiglie di plastica con erogatori gratuiti di acqua potabile in tutte le nostre sedi (clicca qui per saperne di più sulle nostre iniziative in tema di sostenibilità https://www.teoresigroup.com/it/about/sustainability/ ).
# L’offerta è rivolta ad entrambi i sessi in ottemperanza al D.Lgs. 198/2006 ed è aperta anche a candidati appartenenti alle categorie protette e iscritti al collocamento mirato, in conformità con la Legge 68/99 (Art. 1 e Art.18). Crediamo nella --> No translation was found using the current translator. Try another translator?
# Translation error: Découvrez la Vie Apsidienne et vous aussi, devenez ApsidienOn aurait pu demander à Chat GPT de vous démontrer en quoi Apside est l’ESN qu’il vous faut, mais on préfère que vous le découvriez vous-mêmes 😏
# 🔥 Découvrez votre future mission //
# 👉 ContexteClient : Secteur assurance, mutuelle, télécoms,...Méthode de travail : Méthode agile (ou presque)Rôle : Intégré aux équipes de nos clients ou sur nos centres de service, vous contribuez à la réussite de nos projets auxquels vous apporterez vos compétences et votre esprit d’équipe.
# 😎 MissionNos clients des secteurs assurances et mutuelles, recherchent un Ingénieur sécurité/cybersécurité pour analyser, traiter les menaces d’intrusion et définir les plans d’action nécessaires à leurs corrections ou leur anticipation. Vos missions seront :Accompagner nos clients dans l’identification des risques qui pèsent sur leurs systèmes par des méthodes d’analyse de risque (EBIOS, ISO 27005…)Analyser les besoins fonctionnels et techniques de nos clients pour leur apporter un éclairage sur les mesures/recommandations de sécurité adaptées à leurs enjeux.Organiser la prévention des risques en définissant et en mettant en place les stratégies de gouvernance cybersécurité, les processus et politiques de sécurité pour nos clientsElaborer des tableaux de bords sécurité et réaliser des reportings réguliers auprès des décideursRéaliser des audits de maturité et/ou de conformité sur la base des standards applicables
# Vous rejoignez donc une dynamique locale et contribuez à l’évolution de votre agence en ayant la possibilité de :Participer au recrutement et au mentorat de vos futurs collèguesVous investir dans la vie d’agence
#
# 📍 LocalisationAu Mans ou en périphérie selon les projets !Accessible en bus/tram, ou à proximité de la gare.
# 🔮 Futur Apsidien, qui êtes-vous ? //
# Vous maîtrisez la sécurité des systèmes d’informationVous avez des compétences en développement informatiqueVous avez une connaissance de principales méthodologies d’analyse de risques (EBIOS, ISO 27005, …), des contraintes règlementaires (LPM, NIS, RGPD, II901, …) et des référentiels de sécurité (ISO 2700x, NIST, ANSSI, …)· Vous maitrisez les processus standards de CyberSécurité (Incidents, Vulnérabilités, Threat Intelligence…)Vous êtes un très bon communiquant, tant à l’oral qu’à l’écrit.Vous êtes reconnus pour vos qualités d'écoute, de management, de leadership et de persévérance.
#
# 💰 Le package salarial que nous vous proposons //
# Contrat : CDIRémunération : Selon votre profil (D’abord on échange, on comprend vos compétences/aspirations professionnelles et ensuite on s’entend sur le salaire.)Avantages groupe : carte ticket restaurant Swile, prime de mobilité, mutuelle prise en charge à 65%, accord télétravail, prime de cooptationAvantages agence : champ supplémentaire pour évènements propres (avantages CE, afterwork event techniques, communauté techlead etc.)Formation : cours particuliers d’anglais en interne, accès à un catalogue de formations grâce à notre plateforme en e-learning (Academy by Apside) ou via nos organismes partenaires.
#
# 😏 Apside a suscité votre curiosité ? //
# Apside est un partenaire de confiance qui accompagne ses clients à créer de la valeur et à adresser leurs enjeux stratégiques en leur mettant à disposition des expertises technologiques (Data / IA, Cloud, Cyber) et une expérience sectorielle (Industrie, Banque, Assurance, Service, Secteur Public). Pour un accompagnement global, le groupe propose des offres transverses autour du Handicap (Apsid’EA), du Digital Learning, et du Conseil.
#
# 🤔 Et votre place dans tout ça ? //
# Notre volonté est de vous accompagner dans la construction et l’épanouissement de votre carrière.Rejoindre Apside, c'est concevoir et réaliser votre projet personnel et professionnel. Apside vous offre l'opportunité de mener votre carrière au sein de nos 28 agences, en France comme à l'international. Que vous souhaitiez travailler à Paris ou à Montréal, nous vous accompagnons dans vos souhaits de mobilité, de la phase de réflexion jusqu’à l’intégration en agence.
# Engagée pour un monde plus inclusif et plus responsable, Apside place l'humain au cœur de son activité. Nous garantissons un environnement épanouissant, respectueux de toutes les diversités : handicap, genre, orientation, origine, religion, âge ou profil neurologique.Rejoindre Apside, c'est valoriser vos forces et singularités au service de projets ambitieux. Découvrez notre démarche RSE ainsi que notre vision de l’Entreprise Engagée.
# Rejoignez l’aventure Apsidienne et découvrez notre vision d’une ESN singulière et résiliente 🚀
# Notre process de recrutement :📱 Echange téléphonique | Préqualification et définition de vos attentes🔎 Entretien RH | Echange sur votre parcours et votre projet professionnel, présentation du groupe et de ses valeurs🚀 Entretien Tech | Partage d’expériences, questions opérationnelles et techniques✅ Notre proposition | Echange avec votre futur manager, présentation de la proposition de collaboration : --> No translation was found using the current translator. Try another translator?
# Translation error: Bioimis Accademia Alimentare · Padua, Veneto, Italy (Hybrid) --> No translation was found using the current translator. Try another translator?
# Translation error: Xebia · European Union (Remote) --> No translation was found using the current translator. Try another translator?
# Translation error: Oracle · Czechia (Remote) --> No translation was found using the current translator. Try another translator?
# Translation error: BCG Platinion · Stockholm, Stockholm County, Sweden --> No translation was found using the current translator. Try another translator?
# Translation error: Atos · Poland (Remote) --> No translation was found using the current translator. Try another translator?
