# %% [markdown]
# ### Translation task
# Europe is home to 24 official different languages. Although there are not many countries recognizing English as an official language, it is widely known that you can communicate in that language on most of the continent. Moreover, knowledge of English has become a necessity for those working in the IT industry and it represents the predominant language of communication in the technical domain as it facilitates global collaboration.
#
# Currently, our dataset combines multiple european languages across the samples obtained. Having English as the language of the dataset is ideal, and in this notebook we are going to, basically, detect the languages per row and, if the ad is not in english, we'll translate it to this language to ensure data consistency.
# The final dataset contains all job postings in English, allowing for uniform text analysis.
#
# ### Importing libraries

# %%
import pandas as pd
from langdetect import detect, DetectorFactory
from deep_translator import GoogleTranslator
import json
import os

# %% [markdown]
# ### Defining paths
# The described translation task is going to be performed per iteration, this will allow us to have a manageable amount of rows per iteration. This is why we'll use the "li_jobs.json" found in the data folder indicated, and the output will be in the folder of the corresponding iteration.

# %%
main_file="li_jobs.json"
output = "tr_li_jobs.json"
data_folder="data/14"
main_file_path = os.path.join(data_folder, main_file)
output_path = os.path.join(data_folder, output)

# %%
# Load the JSON file and check the number of rows
df_initial = pd.read_json(main_file_path)
row_count = df_initial.shape[0]
print(row_count)
# Out:
# 14457

# %%
# checking the first 10 rows of the dataframe
df_initial.head(10)
# Out:
#                                          Title  \
# 0          Security Program Management Trainee
# 1                     Cybersecurity Internship
# 2                     Cyber Security Evaluator
# 3                       Cybersecurity Engineer
# 4  Cybersecurity Vulnerability Junior Analyst
# 5                       Cybersecurity Engineer
# 6               Information Security Architect
# 7                   Analista de ciberseguridad
# 8            2026 Grad Program, Cyber Security
# 9                             Security Analyst
#
#                                          Description  \
# 0  We are a leading company in the global pool & ...
# 1  We are a cybersecurity laboratory part of Appl...
# 2  Job Description:\n\nJob Description And Tasks\...
# 3  A Snapshot of Your Day\n\nJoin our dynamic tea...
# 4  NTT DATA somos todas las personas que la forma...
# 5  ¿Listo para impulsar la movilidad sostenible? ...
# 6  We are seeking a highly skilled Information Se...
# 7  Participa en innovadores proyectos del sector ...
# 8  At Bending Spoons, we’re striving to build one...
# 9  The mission of Arkose Labs is to create an onl...
#
#                                  Primary Description  \
# 0  Fluidra · Sant Cugat del Vallès, Catalonia, Sp...
# 1  jtsec Beyond IT Security · Granada, Andalusia,...
# 2  Airbus Helicopters · Albacete, Castile-La Manc...
# 3  Siemens Energy · Zamudio, Basque Country, Spai...
# 4  NTT DATA Europe & Latam · Madrid, Community of...
# 5  CAF (Construcciones y Auxiliar de Ferrocarrile...
# 6  Mercedes-Benz Group Services Madrid · Málaga, ...
# 7        ALTEN Spain · Vigo, Galicia, Spain (Hybrid)
# 8  Bending Spoons · Valencia, Valencian Community...
# 9  Arkose Labs · Barcelona, Catalonia, Spain (Hyb...
#
#                                       Detail URL  \
# 0  https://www.linkedin.com/jobs/view/4267500135
# 1  https://www.linkedin.com/jobs/view/4293917474
# 2  https://www.linkedin.com/jobs/view/4294759102
# 3  https://www.linkedin.com/jobs/view/4229281486
# 4  https://www.linkedin.com/jobs/view/4292792512
# 5  https://www.linkedin.com/jobs/view/4261954668
# 6  https://www.linkedin.com/jobs/view/4293756052
# 7  https://www.linkedin.com/jobs/view/4289851418
# 8  https://www.linkedin.com/jobs/view/4299031636
# 9  https://www.linkedin.com/jobs/view/4264973762
#
#                                   Location  \
# 0  Sant Cugat del Vallès, Catalonia, Spain
# 1                Granada, Andalusia, Spain
# 2       Albacete, Castile-La Mancha, Spain
# 3           Zamudio, Basque Country, Spain
# 4       Madrid, Community of Madrid, Spain
# 5           Zamudio, Basque Country, Spain
# 6                 Málaga, Andalusia, Spain
# 7                     Vigo, Galicia, Spain
# 8     Valencia, Valencian Community, Spain
# 9              Barcelona, Catalonia, Spain
#
#                                                Skill Insight Job State  \
# 0  Skills: Security Management, Attention to Deta...            LISTED
# 1  Skills: Computer Science, Reverse Engineering,...            LISTED
# 2            Skills: English, Cybersecurity, +8 more            LISTED
# 3            Skills: English, Cybersecurity, +8 more            LISTED
# 4  Skills: Ticketing Systems, Vulnerability, +2 more            LISTED
# 5  Skills: Cybersecurity, Information Security, +...            LISTED
# 6    Skills: Spoken English, Cyber-security, +2 more            LISTED
# 7  Skills: Network Security, Malware Analysis, +3...            LISTED
# 8          Skills: English, Countermeasures, +8 more            LISTED
# 9               Skills: HTML, IT Escalation, +8 more            LISTED
#
#    Poster Id                                      Company Name  \
# 0  361325280                                           Fluidra
# 1  816741539                          jtsec Beyond IT Security
# 2  327764974                                Airbus Helicopters
# 3  139324179                                    Siemens Energy
# 4   51451327                           NTT DATA Europe & Latam
# 5  306038039  CAF (Construcciones y Auxiliar de Ferrocarriles)
# 6  721169224               Mercedes-Benz Group Services Madrid
# 7  978026522                                       ALTEN Spain
# 8  369598437                                    Bending Spoons
# 9  347693922                                       Arkose Labs
#
#                                         Company Logo  \
# 0  https://media.licdn.com/dms/image/v2/C560BAQEn...
# 1  https://media.licdn.com/dms/image/v2/C4E0BAQE9...
# 2  https://media.licdn.com/dms/image/v2/C510BAQHx...
# 3  https://media.licdn.com/dms/image/v2/D4E0BAQHJ...
# 4  https://media.licdn.com/dms/image/v2/D4D0BAQFG...
# 5  https://media.licdn.com/dms/image/v2/C4D0BAQFe...
# 6  https://media.licdn.com/dms/image/v2/D4D0BAQH7...
# 7  https://media.licdn.com/dms/image/v2/C4D0BAQHK...
# 8  https://media.licdn.com/dms/image/v2/D4D0BAQGf...
# 9  https://media.licdn.com/dms/image/v2/D4E0BAQFB...
#
#                  Created At                Scraped At
# 0  2025-07-16T18:27:22.000Z  2025-09-16T15:37:46.304Z
# 1  2025-09-04T15:10:57.000Z  2025-09-16T15:37:46.305Z
# 2  2025-09-06T05:52:10.000Z  2025-09-16T15:37:46.305Z
# 3  2025-05-16T18:46:59.000Z  2025-09-16T15:37:46.306Z
# 4  2025-09-02T15:25:21.000Z  2025-09-16T15:37:46.306Z
# 5  2025-07-10T13:05:07.000Z  2025-09-16T15:37:46.306Z
# 6  2025-09-01T10:00:22.000Z  2025-09-16T15:37:46.307Z
# 7  2025-08-27T11:58:44.000Z  2025-09-16T15:37:46.307Z
# 8  2025-09-11T18:06:03.000Z  2025-09-16T15:37:46.307Z
# 9  2025-07-15T01:33:23.000Z  2025-09-16T15:37:46.307Z

# %% [markdown]
# ### Translation Function
# Detects the language of specified columns and translates non-English text into English. It takes as parameters the DataFrame containing job listings, the number of rows to process and a boolean that indicates if keeping the original text in new columns for comparison is needed. This will be returning the modified DataFrame with translations in the desired columns.

# %%
DetectorFactory.seed = 0  # Ensures consistent language detection

# %%
def detect_and_translate(df, sample_size=row_count, show_original=False):
    # Columns to translate
    translate_cols = ['Title', 'Description', 'Primary Description', 'Specialties', 'Company Description']
    
    # Sample for validation
    sample_df = df.sample(n=sample_size, random_state=42).copy()

    def translate_text(text):
        # Detects language and translates to English, splitting if >5000 chars due to an API limitation.
        if pd.isna(text) or text.strip() == "":
            return text  # Skip empty or NaN values
        try:
            lang = detect(text)
            if lang != "en":
                if len(text) > 5000:
                    # Split into chunks under 5000 chars
                    chunks = []
                    start = 0
                    while start < len(text):
                        end = min(start + 4999, len(text))  # Max chunk size 4999
                        # Try to split at a natural boundary (period or space)
                        if end < len(text):
                            last_period = text.rfind('.', start, end)
                            last_space = text.rfind(' ', start, end)
                            split_point = max(last_period, last_space) if max(last_period, last_space) > start else end
                            end = split_point if split_point > start else end
                        chunks.append(text[start:end])
                        start = end + 1 if end < len(text) and text[end] in '. ' else end
                    # Translate each chunk and join
                    translated_chunks = []
                    for chunk in chunks:
                        if chunk.strip():  # Only translate non-empty chunks
                            translated_chunks.append(GoogleTranslator(source=lang, target="en").translate(chunk))
                        else:
                            translated_chunks.append(chunk)
                    return ' '.join(translated_chunks)
                else:
                    return GoogleTranslator(source=lang, target="en").translate(text)
        except Exception as e:
            print(f"Translation error: {e}")
            return text  # Return original text if translation fails
        return text  # Return original text if English

    # Apply translation function
    for col in translate_cols:
        if col in sample_df.columns:
            if show_original:
                # Store original text in a new column
                sample_df[f"{col}_original"] = sample_df[col]
            for idx, value in enumerate(sample_df[col]):
                if idx % 100 == 0 and idx > 0:
                    print(f"Processed {idx} records")
            # Replace with translated text
                sample_df.at[sample_df.index[idx], col] = translate_text(value)

    return sample_df

# %% [markdown]
# ### Storing results
# Finally, the results are saved in the folder corresponding to the current iteration. A final merging for these translated versions per iteration is required to complete the dataset, and this can be performed in the last step of the merge-data.ipynb file.

# %%
translated_df = detect_and_translate(df_initial, sample_size=row_count, show_original=False)

translated_df = translated_df.to_dict(orient="records")
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(translated_df, f, ensure_ascii=False, indent=2)
# Out:
# Processed 100 records
# Processed 200 records
# Processed 300 records
# Processed 400 records
# Processed 500 records
# Processed 600 records
# Processed 700 records
# Processed 800 records
# Processed 900 records
# Processed 1000 records
# Processed 1100 records
# Processed 1200 records
# Processed 1300 records
# Processed 1400 records
# Processed 1500 records
# Processed 1600 records
# Processed 1700 records
# Processed 1800 records
# Processed 1900 records
# Processed 2000 records
# Processed 2100 records
# Processed 2200 records
# Processed 2300 records
# Processed 2400 records
# Processed 2500 records
# Processed 2600 records
# Processed 2700 records
# Processed 2800 records
# Processed 2900 records
# Processed 3000 records
# Processed 3100 records
# Processed 3200 records
# Processed 3300 records
# Processed 3400 records
# Processed 3500 records
# Processed 3600 records
# Processed 3700 records
# Processed 3800 records
# Processed 3900 records
# Processed 4000 records
# Processed 4100 records
# Processed 4200 records
# Processed 4300 records
# Processed 4400 records
# Processed 4500 records
# Processed 4600 records
# Processed 4700 records
# Processed 4800 records
# Processed 4900 records
# Processed 5000 records
# Processed 5100 records
# Processed 5200 records
# Processed 5300 records
# Processed 5400 records
# Processed 5500 records
# Processed 5600 records
# Processed 5700 records
# Processed 5800 records
# Processed 5900 records
# Processed 6000 records
# Processed 6100 records
# Processed 6200 records
# Processed 6300 records
# Processed 6400 records
# Processed 6500 records
# Processed 6600 records
# Processed 6700 records
# Processed 6800 records
# Processed 6900 records
# Processed 7000 records
# Processed 7100 records
# Processed 7200 records
# Processed 7300 records
# Processed 7400 records
# Processed 7500 records
# Processed 7600 records
# Processed 7700 records
# Processed 7800 records
# Processed 7900 records
# Processed 8000 records
# Processed 8100 records
# Processed 8200 records
# Processed 8300 records
# Processed 8400 records
# Processed 8500 records
# Processed 8600 records
# Processed 8700 records
# Processed 8800 records
# Processed 8900 records
# Processed 9000 records
# Processed 9100 records
# Processed 9200 records
# Processed 9300 records
# Processed 9400 records
# Processed 9500 records
# Processed 9600 records
# Processed 9700 records
# Processed 9800 records
# Processed 9900 records
# Processed 10000 records
# Processed 10100 records
# Processed 10200 records
# Processed 10300 records
# Processed 10400 records
# Processed 10500 records
# Processed 10600 records
# Processed 10700 records
# Processed 10800 records
# Processed 10900 records
# Processed 11000 records
# Processed 11100 records
# Processed 11200 records
# Processed 11300 records
# Processed 11400 records
# Processed 11500 records
# Processed 11600 records
# Processed 11700 records
# Processed 11800 records
# Processed 11900 records
# Processed 12000 records
# Processed 12100 records
# Processed 12200 records
# Processed 12300 records
# Processed 12400 records
# Processed 12500 records
# Processed 12600 records
# Processed 12700 records
# Processed 12800 records
# Processed 12900 records
# Processed 13000 records
# Processed 13100 records
# Processed 13200 records
# Processed 13300 records
# Processed 13400 records
# Processed 13500 records
# Processed 13600 records
# Processed 13700 records
# Processed 13800 records
# Processed 13900 records
# Processed 14000 records
# Processed 14100 records
# Processed 14200 records
# Processed 14300 records
# Processed 14400 records
# Processed 100 records
# Translation error: Vous aimez faire le lien entre l’informatique et le terrain ? 🕹 Rejoignez-nous pour déployer, maintenir et sécuriser nos systèmes IT/OT aux côtés des équipes de production et faire tourner notre usine connectée 🏭
# ✈ Un mot sur Safran Blades
# Inaugurée en juin 2025 à Marchin, Safran Blades est un nouveau site industriel qui vient renforcer l’expertise industrielle de Safran Aero Boosters. Ce projet a été créé en partenariat avec les pouvoirs publics fédéraux belges et wallons, Wallonie-Entreprendre et la Société Fédérale des Participations et d’Investissement (SFPIM). Le site a été entièrement transformé pour devenir un centre d’excellence technologique de 10.000 m² dédié à la fabrication d’aubes de compresseur en titane pour moteurs d’avion incarnant les principes de l’industrie 4.0.
# Actuellement en phase d’industrialisation, Safran Blades vise une montée en cadence progressive avec un objectif de plus de 2.000 aubes produites par jour dès 2028. Avec une approche agile et une culture d’amélioration continue, l’usine rassemble déjà plus de 70 collaborateurs investis et convaincus par le projet.
# Pourquoi rejoindre Safran Blades ?
# Un projet industriel d’envergure et porteur de sens : vous participez à la montée en cadence d’un site en pleine croissance et au développement industriel de la Wallonie ;Des technologies de pointe : vous travaillez avec des équipements industriels de dernière génération, où tout est à produire ;Un management collaboratif : fondé sur la confiance, l’autonomie et où la proactivité est encouragée ;Un esprit d’équipe soudé et bienveillant : vous rejoignez l’équipe qualité qui est en interaction constante avec l’atelier et les bureaux, toujours à la recherche d’amélioration et à l’affut de l’efficacité ;Un parcours évolutif : vous bénéficiez d’un accompagnement individualisé dès l’entrée, avec un plan de formation sur mesure et des perspectives de développement dans d’autres domaines techniques par la suite.
# Alors, ça vous dit de nous rejoindre ? Pour accompagner le lancement de cette nouvelle usine, nous recherchons un·e Technicien IT/OT pour notre site de 📍 Marchin.
# 🎯 Parlons de votre future mission
# En tant que Technicien IT/OT, votre rôle sera de garantir la disponibilité, la performance et la sécurité des systèmes IT et OT de notre usine, en soutenant les équipes de production dans un environnement industriel 4.0.
# Vos missions sont donc de :
# Déployer et configurer les infrastructures IT/OT (serveurs, stockage, réseaux, virtualisation, containerisation).Maintenir la disponibilité des systèmes critiques (MES, GMAO, bases de données) et assurer un support technique réactif aux équipes métiers.Superviser les opérations de monitoring, de sauvegarde, de restauration et de gestion des incidents.Intégrer de nouvelles solutions technologiques et coordonner leur mise en production avec les équipes internes et les fournisseurs.Sécuriser les environnements IT/OT en appliquant les bonnes pratiques de cybersécurité et de gestion des accès.Collaborer avec les équipes internes pour optimiser la collecte, l’exploitation et l’historisation des données industrielles.
# 🧩 Et en complément ?
# Vous rejoignez l’équipe digitalisation 4.0 composée d’une quinzaine de personnes, dédiée aux sujets de la digitalisation 4.0 (Processus, Automation, Robotique et systèmes informatiques industriels) et de la fiabilité de la donnée au sein de notre usine. Ce qui la caractérise ? Un esprit d’échange, de défi collectif et un intérêt commun pour transformer la donnée industrielle en valeur concrète.
# Votre Manager est Geoffroy, Responsable du Pôle Digitalisation 4.0. Son style managérial est basé sur l’atteinte de résultats, l’autonomie et l’engagement. « Just good enough never change the world », est sa devise ! Au sein de son équipe, vous aurez l’occasion d’apprendre, d’oser et de vous challenger. Geoffroy attend l’implication de tous tout en restant un soutien et en étant à l’écoute des besoins de son équipe.
# 🙌 Et si on parlait de vous ?
# Vos compétences techniques :
# Bachelier avec une orientation en informatique, systèmes, réseaux ou ingénierie des données ;Expérience de minimum 3 ans dans une fonction similaire. Nous restons néanmoins ouverts à un profil junior ayant une expérience concluante de stage ;Très bonne connaissance des systèmes (VMware, Linux, Windows) et des réseaux industriels (VLAN, firewall, OPC-UA, MQTT) pour garantir le bon fonctionnement et la sécurité des infrastructures ;Maîtrise des outils de virtualisation et de containerisation (Docker, Kubernetes) pour gérer des applications isolées et flexibles ;Connaissance des bases de données industrielles (PostgreSQL, MongoDB, InfluxDB, Apache Iceberg) et des techniques de traitement de données (ETL) ;Compréhension des enjeux liés à la sécurité, à la gouvernance des données et aux bonnes pratiques DevOps ;Bon niveau d’anglais (B1/B2) pour lire la documentation technique et rédiger des rapports.
# Vos soft skills :
# Curiosité : vous aimez aller sur le terrain, --> No translation was found using the current translator. Try another translator?
# Translation error: Request exception can happen due to an api connection error. Please check your connection and try again
# Processed 200 records
# Processed 300 records
# Translation error: REJOIGNEZ UN COLLECTIF ANIME PAR LE GOUT DU DEFI
#
# Rejoignez Peaksys, la filiale Tech de Cnova, et façonnez l’avenir du e-commerce à grande échelle !
#
# Chez #Peaksys, plus de 600 experts passionnés conçoivent et opèrent des solutions digitales à l’échelle pour tout l’écosystème Cnova (Cdiscount, Octopia, C-Logistics, CnovaPay).
#
# Notre terrain de jeu ?  1 milliard de recherches moteur par an, jusqu’à 1200 commandes par minute lors du Black Friday et un déploiement en production toutes les 7 minutes.
#
# Notre mission : accélérer le business en livrant rapidement des fonctionnalités à forte valeur ajoutée, alliant excellence produit et alignement avec les besoins métiers.
#
# Envie de relever des défis d’envergure ? Rejoignez Peaksys et prenez part à une aventure humaine et technologique hors norme.
#
# Explorez un champ des possibles sans équivalence
#
# Rejoignez Peaksys, venez faire du hors norme votre norme.
#
# Vous intégrerez l’équipe Application Security au sein de la Direction Cybersécurité qui est composée d’une vingtaine de personnes. La direction a la charge de la Conformité IT et de la Cybersécurité de l’ensemble des filiales du groupe Cnova, en lien étroit avec les équipes DPO et Contrôle Interne.
#
# Vous Serez Amené à Intervenir Sur Plusieurs Axes Principaux
#
# Participer à la mise en place de la stratégie de Gouvernance, Risques et Conformité de l'ensemble des filiales de CDISCOUNT,Assurer une gestion de projet transverse avec l’ensemble des équipes et directions du groupe CNOVA sur les audits de sécurité (NIS2, DORA, PCIDSS) :Mener des auditsPiloter les comités de suiviAméliorer les processus d'audits internes,Apporter votre approche sécurité et conformité lors de mise en place de projets concernant l’infrastructure du système d’information ou lors du lancement de projets transverses,Mettre à jour la documentation sécurité du groupe,Participer à la mise en place de la stratégie de résilience du groupe (Gestion de crise, PCA, PRA),Assurer une veille régulière des normes, transposition en interne et renouvellement des certifications/attestations (PCI-DSS, NIS2, DORA, ISO27X…) en lien avec les cabinets d’audit,Accompagner les métiers dans l’intégration de la sécurité dans leurs projets du groupe CNOVAAccompagner l’équipe formation dans la sensibilisation des utilisateurs aux bonnes pratiques de sécurité,Construction, diffusion, présentation de supports de sensibilisation.
# SEREZ-VOUS "THE ONE" 💥 ?
#
# De formation de type école d’ingénieur ou universitaire avec une spécialisation en sécurité informatique, vous justifiez d’une expérience réussie dans la GRC (minimum 5 ans client final ou 3 ans en cabinet de conseils) et justifierez d’une appétence technique en SSI.
#
# Vous possédez une bonne capacité d’analyse, un bon relationnel et une grande capacité à comprendre la criticité des applications.
#
# Vous Maitrisez Les Outils Suivants
#
#  JIRA ou ITSM équivalent Outils Office 365
#
# Vous maitrisez les normes/référentiels et méthodologies suivantes :
#
#  ISO 27001 et ISO 27002 ISO 27005 PCI-DSS EBIOS RM
#
# Vous Connaissez Les Méthodologies Suivantes
#
#  ISO 22301 DORA NIS2
#
# Curieux et rigoureux, vous saurez contribuer à des projets d’envergure et être reconnu pour votre expertise dans la GRC et votre maitrise de la gestion de projet.
#
# Passionné, vous cherchez une société où vous pourrez mettre en œuvre votre créativité et votre expertise pour relever nos défis quotidiens.
#
# Vous réalisez une veille constante sur les nouvelles réglementations qui encadrent notamment l’IA.
#
# Peaksys est un employeur investi en faveur de la diversité : du recrutement à l'évolution professionnelle, nous garantissons l'égalité des chances à tous nos collaborateurs.
#
# Vous êtes persuadé que l’avenir appartient à celles et ceux qui osent faire bouger les lignes ? Nous aussi. Alors, Inventez-tout, Révélez-vous !
#
# Venez développer vos compétences et votre employabilité dans un environnement de travail unique :
#
# 🏡 : Un accord télétravail pouvant aller jusqu’à 2 jours par semaine,
#
# 🌉 : Des locaux modernes et situés au bord de la Garonne en plein cœur des Bassins à Flots, hub de la tech Bordelaise,
#
# 🎤 : Des animations, conférences, et temps d’échanges dédiés avec la Direction,
#
# 🎓 : Une offre de formation innovante et à la pointe des nouvelles technologies,
#
# 🏆 : De nombreux labels obtenus (Great Place To Work, Happy Trainees, AFNOR "Diversité" et "Egalité F/H"),
#
# 🛒 : Avantages exclusifs Cdiscount,
#
# 🎢 : Des offres avantageuses grâce au CSE (cinéma, parcs de loisirs, concerts),
#
# 🌍 : L’opportunité d’être acteur d’initiatives RSE et liées à la Diversité : (HandiTeam, GreenTeam),
#
# 👶🏽 : Des places en crèches et un dispositif de garde d’enfant en urgence,
#
# 💰 : Des plans d'épargnes (PEE, PERCOL, abondement employeur sur versements volontaires),
#
# Et Les Indispensables
#
# 🍔 cartes restaurants, 🌅 chèques vacances, 🩹 mutuelle adaptée à tous, 🚎 remboursement à hauteur de 50% des titres de transport.
#
# Les Prochaines Étapes
#
# Un entretien téléphonique RH avec Hélène , votre contact RH --> No translation was found using the current translator. Try another translator?
# Processed 400 records
# Processed 500 records
# Processed 600 records
# Processed 700 records
# Processed 800 records
# Processed 900 records
# Processed 1000 records
# Processed 1100 records
# Translation error: Découvrez la Vie Apsidienne et vous aussi, devenez ApsidienOn aurait pu demander à Chat GPT de vous démontrer en quoi Apside est l’ESN qu’il vous faut, mais on préfère que vous le découvriez vous-mêmes 😏
# 🔥 Découvrez votre future mission //
# 👉 ContexteClient : Secteur assurance, mutuelle, télécoms,...Méthode de travail : Méthode agile (ou presque)Rôle : Intégré aux équipes de nos clients ou sur nos centres de service, vous contribuez à la réussite de nos projets auxquels vous apporterez vos compétences et votre esprit d’équipe.
# 😎 MissionNos clients des secteurs assurances et mutuelles, recherchent un Ingénieur sécurité/cybersécurité pour analyser, traiter les menaces d’intrusion et définir les plans d’action nécessaires à leurs corrections ou leur anticipation. Vos missions seront :Accompagner nos clients dans l’identification des risques qui pèsent sur leurs systèmes par des méthodes d’analyse de risque (EBIOS, ISO 27005…)Analyser les besoins fonctionnels et techniques de nos clients pour leur apporter un éclairage sur les mesures/recommandations de sécurité adaptées à leurs enjeux.Organiser la prévention des risques en définissant et en mettant en place les stratégies de gouvernance cybersécurité, les processus et politiques de sécurité pour nos clientsElaborer des tableaux de bords sécurité et réaliser des reportings réguliers auprès des décideursRéaliser des audits de maturité et/ou de conformité sur la base des standards applicables
# Vous rejoignez donc une dynamique locale et contribuez à l’évolution de votre agence en ayant la possibilité de :Participer au recrutement et au mentorat de vos futurs collèguesVous investir dans la vie d’agence
#
# 📍 LocalisationAu Mans ou en périphérie selon les projets !Accessible en bus/tram, ou à proximité de la gare.
# 🔮 Futur Apsidien, qui êtes-vous ? //
# Vous maîtrisez la sécurité des systèmes d’informationVous avez des compétences en développement informatiqueVous avez une connaissance de principales méthodologies d’analyse de risques (EBIOS, ISO 27005, …), des contraintes règlementaires (LPM, NIS, RGPD, II901, …) et des référentiels de sécurité (ISO 2700x, NIST, ANSSI, …)· Vous maitrisez les processus standards de CyberSécurité (Incidents, Vulnérabilités, Threat Intelligence…)Vous êtes un très bon communiquant, tant à l’oral qu’à l’écrit.Vous êtes reconnus pour vos qualités d'écoute, de management, de leadership et de persévérance.
#
# 💰 Le package salarial que nous vous proposons //
# Contrat : CDIRémunération : Selon votre profil (D’abord on échange, on comprend vos compétences/aspirations professionnelles et ensuite on s’entend sur le salaire.)Avantages groupe : carte ticket restaurant Swile, prime de mobilité, mutuelle prise en charge à 65%, accord télétravail, prime de cooptationAvantages agence : champ supplémentaire pour évènements propres (avantages CE, afterwork event techniques, communauté techlead etc.)Formation : cours particuliers d’anglais en interne, accès à un catalogue de formations grâce à notre plateforme en e-learning (Academy by Apside) ou via nos organismes partenaires.
#
# 😏 Apside a suscité votre curiosité ? //
# Apside est un partenaire de confiance qui accompagne ses clients à créer de la valeur et à adresser leurs enjeux stratégiques en leur mettant à disposition des expertises technologiques (Data / IA, Cloud, Cyber) et une expérience sectorielle (Industrie, Banque, Assurance, Service, Secteur Public). Pour un accompagnement global, le groupe propose des offres transverses autour du Handicap (Apsid’EA), du Digital Learning, et du Conseil.
#
# 🤔 Et votre place dans tout ça ? //
# Notre volonté est de vous accompagner dans la construction et l’épanouissement de votre carrière.Rejoindre Apside, c'est concevoir et réaliser votre projet personnel et professionnel. Apside vous offre l'opportunité de mener votre carrière au sein de nos 28 agences, en France comme à l'international. Que vous souhaitiez travailler à Paris ou à Montréal, nous vous accompagnons dans vos souhaits de mobilité, de la phase de réflexion jusqu’à l’intégration en agence.
# Engagée pour un monde plus inclusif et plus responsable, Apside place l'humain au cœur de son activité. Nous garantissons un environnement épanouissant, respectueux de toutes les diversités : handicap, genre, orientation, origine, religion, âge ou profil neurologique.Rejoindre Apside, c'est valoriser vos forces et singularités au service de projets ambitieux. Découvrez notre démarche RSE ainsi que notre vision de l’Entreprise Engagée.
# Rejoignez l’aventure Apsidienne et découvrez notre vision d’une ESN singulière et résiliente 🚀
# Notre process de recrutement :📱 Echange téléphonique | Préqualification et définition de vos attentes🔎 Entretien RH | Echange sur votre parcours et votre projet professionnel, présentation du groupe et de ses valeurs🚀 Entretien Tech | Partage d’expériences, questions opérationnelles et techniques✅ Notre proposition | Echange avec votre futur manager, présentation de la proposition de collaboration : --> No translation was found using the current translator. Try another translator?
# Processed 1200 records
# Processed 1300 records
# Processed 1400 records
# Translation error: Senior Controller bij gemeente AmsterdamMeer dan spreadsheets: bouw mee aan een toekomstbestendig Amsterdam.
# Op dinsdag 30 september nodigen we je uit voor een Meet & Greet in het H’ART Museum aan de Amstel. Ontdek de rol van Senior Controller bij de Directie Middelen & Control, luister naar inspirerende verhalen van collega’s en ontmoet onze recruiters én hiring managers tijdens een informele borrel. 👉 Meld je eenvoudig aan via de sollicitatieknop – een cv uploaden is niet nodig. Na je inschrijving neem ik, Anette Appelhof (senior recruiter DMC), persoonlijk contact met je op.
# Programma Meet & Greet – dinsdag 30 september 📍 Museum H’ART aan de Amstel 51☕ 16:45 uur – Inloop en ontvangst🙋 17:00 uur – Opening & Werken bij Amsterdam📖 17:15 uur – Collega’s DMC delen hun verhaal🏙️ 17:40 uur – Collega’s F&I vertellen hun ervaringen🎤 18:05 uur – Panelgesprek met collega’s van DMC & F&I: inkijkje in cultuur, samenwerking en toekomst🍇 18:30 – 20:00 uur – Informele netwerkborrel met vullende bites & persoonlijke 🫱🏽 🫲🏼ontmoetingen met recruiters en hiring managers
# De uitdagingAmsterdam is nooit af. Er wordt gebouwd, vernieuwd, gedigitaliseerd en bijgestuurd – soms allemaal tegelijk. Als Senior Controller houd jij grip op die beweging. Je adviseert strategisch over financiële sturing, risico’s en governance. Niet vanaf de zijlijn, maar midden in het speelveld waar politiek, organisatie en maatschappij elkaar raken.
# Over Directie Middelen en Control (DMC)Met een begroting van € 8 miljard heeft de gemeente Amsterdam de grootste gemeentebegroting van Nederland. DMC is onderdeel van Bestuur en Organisatie en adviseert en ondersteunt het gemeentebestuur en de ambtelijke top op het gebied van financiën en interne procesbeheersing. Binnen DMC werken zo’n 70 controllers die een sleutelrol spelen bij het beheerst realiseren van de grote opgaven van de stad.
# De functieAls strategisch adviseur bij de gemeente Amsterdam bevind je je in een speelveld waar maatschappelijke ambities, geldende kaders en politieke realiteit elkaar ontmoeten. Jij schrijft adviezen die niet alleen correct zijn volgens de regels, maar die ook standhouden in een dynamiek waar belangen en prioriteiten elkaar kunnen kruisen.
# Je bent sparringpartner voor managers, directeuren, het gemeentelijk managementteam en het college. Dat vraagt om meer dan cijfers paraat hebben: het vraagt om het vermogen om de juiste vragen te stellen, de onderstromen te herkennen en soms het onuitgesprokene te benoemen.
# Oplossingsgericht werken is je tweede natuur. Je waarborgt de integraliteit van vraagstukken, weegt context zorgvuldig en houdt steeds het bredere concernperspectief in het vizier. Niet om extra lagen te creëren, maar om de essentie te bewaren.
# Je doet dit in programmateams die bewust interdisciplinair zijn samengesteld. Want de grote vraagstukken van de stad vragen niet om één discipline die roept dat hij het weet, maar om meerdere perspectieven die samen tot een werkbare oplossing komen.
# Control organiseren we wendbaar en flexibel. Dat betekent dat jij je inzet waar de vraagstukken het meest urgent zijn – en dat je na verloop van tijd van werkpakket wisselt. Zo blijf je onafhankelijk, houd je je blik scherp en voorkom je dat je adviezen voorspelbaar worden.
# Dit doe je op een gemiddelde dagGeen dag hetzelfde – maar wel in één domein dat bij jou past. Jij kiest (of beter: samen kiezen we) het werkveld waar jouw kennis en ambitie het meeste waarde hebben. In dat domein adviseer je over complexe vraagstukken, breng je cijfers, risico’s en beleid samen en zorg je dat keuzes standhouden in de politieke en bestuurlijke realiteit van Amsterdam. Je kunt je verdiepen in één van deze domeinen:I-domein – investeringen in digitalisering, cloud, data en informatiebeveiliging.Bedrijfsvoering – van nieuwe cao tot huisvesting en een nieuw financieel systeem.Sociaal domein – meer vraag, stijgende kosten, beperkt budget.Fysiek domein – duurzame stadsuitbreiding, energietransitie en klimaatadaptatie.
# Dit breng je mee als Senior ControllerWo-werk- en -denkniveau.Ervaring met (overheids)financiën, planning & control en verantwoording in een dynamische omgeving.Een brede blik: deze rol gaat nadrukkelijk verder dan alleen financial control.Ambitie om voor de gemeente Amsterdam te werken – óók als je nog geen ervaring hebt in de publieke sector.
# Je herkent jezelf in deze competenties:Adviseren & communicatie – je brengt complexe zaken helder over en weet te verbinden.Omgevingsbewustzijn & inlevingsvermogen – je begrijpt de dynamiek van stad, bestuur en samenleving.Samenwerking & resultaatgerichtheid – je zoekt actief de verbinding en houdt oog voor het gezamenlijke doel.Analytisch vermogen & helikopterview – je ziet details, maar verliest de hoofdlijn nooit uit het oog.Overtuigingskracht – je weet standpunten stevig en toch constructief neer te zetten.
# In het kort onze arbeidsvoorwaarden:Salaris dat past bij je ervaring – maximaal € 6.308,- (schaal 11), € 7.128,- (schaal 12) of € 7.705,- --> No translation was found using the current translator. Try another translator?
# Processed 1500 records
# Processed 1600 records
# Processed 1700 records
# Translation error: ¡Únete al equipo de SII Group Spain y ayúdanos a impulsar la transformación digital e innovación!
# 🌐 ¿Te apasiona la ciberseguridad y tienes experiencia en administración de firewalls y seguridad de red? 🚀Estamos incorporando un/a IT Security Operations Engineer, que tendrá un papel clave en proyectos de Production Security, participando en la gestión de firewalls, proxies y revisión de arquitecturas dentro de un entorno internacional.
# 📌 ResponsabilidadesBuscamos un/a profesional que se encargue de mantener y mejorar la seguridad de la infraestructura, con foco en firewalls, proxies, accesos privilegiados y revisión de arquitecturas. Entre sus principales funciones:Administración de firewalls (Checkpoint, Fortinet): implementación de políticas, revisión de reglas, soporte en incidentes.Uso y optimización de herramientas como Tufin SecureTrack / SecureChange.Administración de Socks Proxies para accesos específicos.Gestión y control de accesos privilegiados (PAM).Revisión de arquitecturas de red y aplicaciones, asegurando el cumplimiento de principios de seguridad.Propuesta de mejoras de arquitectura y herramientas.Soporte a equipos de producción en buenas prácticas de seguridad.Participación en proyectos internos del equipo.Guardias de primer nivel y cobertura de festivos
# 🎯 Requisitos1-3 años de experiencia en entornos de infraestructura IT. Conocimiento sólido en seguridad IT y administración de equipos de seguridad.Experiencia con Checkpoint y Fortinet (manager y firewall).Conocimientos de Tufin SecureTrack / SecureChange.Sólidos fundamentos en TCP/IP, LAN, WAN y principios de seguridad de red.Experiencia en gestión de accesos privilegiados (PAM). Inglés fluido (mín. B2). Francés valorable. Grado en Informática o similar. Certificaciones en seguridad o ITIL deseables.
# Se valoraráConocimiento de sistemas Unix (Solaris) y Windows.Familiaridad con SecurID, ACE Server, HSM.Experiencia con WAF, IDS/IPS y scripting.
# ¿Quiénes somos?
# En SII Group, con más de 16.000 profesionales en 20 países, ofrecemos servicios de IT, Ingeniería y Consultoría que impulsan la transformación digital en múltiples industrias. Nos guiamos por los pilares estratégicos: Growth, People & ESG, manteniendo una cultura de confianza y excelencia reconocida por nuestro equipo con la certificación Great Place to Work.
# Let’s Tech Together
# Let’s Tech Together es nuestra promesa y filosofía. Nos atrevemos a innovar, a tomar la iniciativa y a construir un futuro tecnológico juntos. Valoramos la autonomía, la experimentación y la inclusión, creando un entorno donde cada idea cuenta y donde cada miembro del equipo puede crecer profesional y personalmente
# ¿Qué te ofrecemos?
# 24 días de vacaciones para que desconectes: 🏖️Disfruta de un merecido descanso con 24 días hábiles de vacaciones, para que disfrutes de tiempo de calidad!
# Contrato indefinido: 📄Contrato indefinido, brindándote seguridad y confianza en tu futuro profesional.
# Jornada intensiva todos los viernes y el mes de agosto: 🗓️¡Dale la bienvenida al fin de semana antes!Disfruta de jornadas intensivas los viernes y durante todo el mes de agosto para optimizar tu tiempo libre y equilibrar tu vida laboral."
# Retribución flexible: 💼Te ofrecemos una retribución a la carta pudiendo elegir diferentes productos tales como seguro de salud, tickets de comida, transporte, guardería, plataformas de bienestar (WellHub), etc..
# Metodología SmartWorking: 🌐Nos adaptamos a tu estilo de vida con nuestra metodología SmartWorking, que fomenta la flexibilidad y el teletrabajo, permitiéndote alcanzar un equilibrio entre tu carrera y tus compromisos personales.
# Oficinas Wellbeing: 🎾☕En nuestra sede de la Agencia West, contamos con instalaciones de bienestar de las que podrás disfrutar: gimnasio equipado, pista de pádel, rocódromo, clases individuales… Además, disponemos de Coffee Corner con café de especialidad para que puedas relajarte y disfrutar de tu pausa.
# IT&Engineering Academy: 🎓Sigue creciendo con nosotros a través de nuestra IT&Engineering Academy, el campus de formación que SII Group Spain pone a tu disposición para que puedas seguir desarrollando nuevas competencias (Hard y Soft Skills), impulsando tu crecimiento profesional y personal.Además contamos con licencias de Coursera, formación AdHoc e idiomas. 📚
# Oportunidad de aprender de grandes profesionales: 👨 🏫Aprovecha la oportunidad de aprender de los mejores. Nuestros programas de coaching y mentoring te brindan la guía y el apoyo necesarios para alcanzar tu máximo potencial.Tenemos Convenios con distintas Asociaciones y Colegios de Ingenieros, brindándote laposibilidad de acceder a formaciones y normativa específica. 📝
# Proyección de futuro y estabilidad: 🚀Diseña tu propio camino hacia el éxito con nuestro plan de carrera personalizado, que te ofrece proyección de futuro y estabilidad a largo plazo en un ambiente de trabajo colaborativo y motivador.
# Movilidad geográfica: 🌍Explora nuevas oportunidades y experiencias internacionales con nuestra opción de --> No translation was found using the current translator. Try another translator?
# Processed 1800 records
# Processed 1900 records
# Processed 2000 records
# Processed 2100 records
# Processed 2200 records
# Processed 2300 records
# Processed 2400 records
# Processed 2500 records
# Processed 2600 records
# Processed 2700 records
# Processed 2800 records
# Translation error: Senior Controller bij gemeente AmsterdamMeer dan spreadsheets: bouw mee aan een toekomstbestendig Amsterdam.
# Op dinsdag 30 september nodigen we je uit voor een Meet & Greet in het H’ART Museum aan de Amstel. Ontdek de rol van Senior Controller bij de Directie Middelen & Control, luister naar inspirerende verhalen van collega’s en ontmoet onze recruiters én hiring managers tijdens een informele borrel. 👉 Meld je eenvoudig aan via de sollicitatieknop – een cv uploaden is niet nodig. Na je inschrijving neem ik, Anette Appelhof (senior recruiter DMC), persoonlijk contact met je op.
# Programma Meet & Greet – dinsdag 30 september 📍 Museum H’ART aan de Amstel 51☕ 16:45 uur – Inloop en ontvangst🙋 17:00 uur – Opening & Werken bij Amsterdam📖 17:15 uur – Collega’s DMC delen hun verhaal🏙️ 17:40 uur – Collega’s F&I vertellen hun ervaringen🎤 18:05 uur – Panelgesprek met collega’s van DMC & F&I: inkijkje in cultuur, samenwerking en toekomst🍇 18:30 – 20:00 uur – Informele netwerkborrel met vullende bites & persoonlijke 🫱🏽 🫲🏼ontmoetingen met recruiters en hiring managers
# De uitdagingAmsterdam is nooit af. Er wordt gebouwd, vernieuwd, gedigitaliseerd en bijgestuurd – soms allemaal tegelijk. Als Senior Controller houd jij grip op die beweging. Je adviseert strategisch over financiële sturing, risico’s en governance. Niet vanaf de zijlijn, maar midden in het speelveld waar politiek, organisatie en maatschappij elkaar raken.
# Over Directie Middelen en Control (DMC)Met een begroting van € 8 miljard heeft de gemeente Amsterdam de grootste gemeentebegroting van Nederland. DMC is onderdeel van Bestuur en Organisatie en adviseert en ondersteunt het gemeentebestuur en de ambtelijke top op het gebied van financiën en interne procesbeheersing. Binnen DMC werken zo’n 70 controllers die een sleutelrol spelen bij het beheerst realiseren van de grote opgaven van de stad.
# De functieAls strategisch adviseur bij de gemeente Amsterdam bevind je je in een speelveld waar maatschappelijke ambities, geldende kaders en politieke realiteit elkaar ontmoeten. Jij schrijft adviezen die niet alleen correct zijn volgens de regels, maar die ook standhouden in een dynamiek waar belangen en prioriteiten elkaar kunnen kruisen.
# Je bent sparringpartner voor managers, directeuren, het gemeentelijk managementteam en het college. Dat vraagt om meer dan cijfers paraat hebben: het vraagt om het vermogen om de juiste vragen te stellen, de onderstromen te herkennen en soms het onuitgesprokene te benoemen.
# Oplossingsgericht werken is je tweede natuur. Je waarborgt de integraliteit van vraagstukken, weegt context zorgvuldig en houdt steeds het bredere concernperspectief in het vizier. Niet om extra lagen te creëren, maar om de essentie te bewaren.
# Je doet dit in programmateams die bewust interdisciplinair zijn samengesteld. Want de grote vraagstukken van de stad vragen niet om één discipline die roept dat hij het weet, maar om meerdere perspectieven die samen tot een werkbare oplossing komen.
# Control organiseren we wendbaar en flexibel. Dat betekent dat jij je inzet waar de vraagstukken het meest urgent zijn – en dat je na verloop van tijd van werkpakket wisselt. Zo blijf je onafhankelijk, houd je je blik scherp en voorkom je dat je adviezen voorspelbaar worden.
# Dit doe je op een gemiddelde dagGeen dag hetzelfde – maar wel in één domein dat bij jou past. Jij kiest (of beter: samen kiezen we) het werkveld waar jouw kennis en ambitie het meeste waarde hebben. In dat domein adviseer je over complexe vraagstukken, breng je cijfers, risico’s en beleid samen en zorg je dat keuzes standhouden in de politieke en bestuurlijke realiteit van Amsterdam. Je kunt je verdiepen in één van deze domeinen:I-domein – investeringen in digitalisering, cloud, data en informatiebeveiliging.Bedrijfsvoering – van nieuwe cao tot huisvesting en een nieuw financieel systeem.Sociaal domein – meer vraag, stijgende kosten, beperkt budget.Fysiek domein – duurzame stadsuitbreiding, energietransitie en klimaatadaptatie.
# Dit breng je mee als Senior ControllerWo-werk- en -denkniveau.Ervaring met (overheids)financiën, planning & control en verantwoording in een dynamische omgeving.Een brede blik: deze rol gaat nadrukkelijk verder dan alleen financial control.Ambitie om voor de gemeente Amsterdam te werken – óók als je nog geen ervaring hebt in de publieke sector.
# Je herkent jezelf in deze competenties:Adviseren & communicatie – je brengt complexe zaken helder over en weet te verbinden.Omgevingsbewustzijn & inlevingsvermogen – je begrijpt de dynamiek van stad, bestuur en samenleving.Samenwerking & resultaatgerichtheid – je zoekt actief de verbinding en houdt oog voor het gezamenlijke doel.Analytisch vermogen & helikopterview – je ziet details, maar verliest de hoofdlijn nooit uit het oog.Overtuigingskracht – je weet standpunten stevig en toch constructief neer te zetten.
# In het kort onze arbeidsvoorwaarden:Salaris dat past bij je ervaring – maximaal € 6.308,- (schaal 11), € 7.128,- (schaal 12) of € 7.705,- --> No translation was found using the current translator. Try another translator?
# Processed 2900 records
# Processed 3000 records
# Translation error: ¡Únete al equipo de SII Group Spain y ayúdanos a impulsar la transformación digital e innovación!
# ¿Tienes experiencia en gestión de accesos privilegiados (PAM) y te apasiona la ciberseguridad? 🚀 Estamos incorporando un/a especialista en Extended Rights Security Analysis, que tendrá un papel clave en proyectos de gestión de identidades y accesos dentro de un entorno internacional.
# 📌 ResponsabilidadesAdministración y gestión de CyberArk, garantizando su seguridad y operatividad.Ejecución de proyectos relacionados con rotación segura de contraseñas.Colaboración con equipos de soporte y project managers en el diseño e implementación de nuevas funcionalidades de gestión de accesos.Gestión del ciclo de vida de cuentas técnicas (provisión, desprovisión, revisiones periódicas).Redacción y mantenimiento de procedimientos y políticas de seguridad alineados con estándares internacionales.
# 🎯 RequisitosExperiencia sólida en CyberArk (CPM, PSM, AIM).Conocimientos en Active Directory (RBAC), MSSQL, Oracle, Windows Server, RHEL y Centrify.Habilidad en scripting (PowerShell).Valorable certificaciones como CISM, CISSP o similares.Nivel alto de inglés.
# ¿Quiénes somos?
# En SII Group, con más de 16.000 profesionales en 20 países, ofrecemos servicios de IT, Ingeniería y Consultoría que impulsan la transformación digital en múltiples industrias. Nos guiamos por los pilares estratégicos: Growth, People & ESG, manteniendo una cultura de confianza y excelencia reconocida por nuestro equipo con la certificación Great Place to Work.
# Let’s Tech Together
# Let’s Tech Together es nuestra promesa y filosofía. Nos atrevemos a innovar, a tomar la iniciativa y a construir un futuro tecnológico juntos. Valoramos la autonomía, la experimentación y la inclusión, creando un entorno donde cada idea cuenta y donde cada miembro del equipo puede crecer profesional y personalmente
# ¿Qué te ofrecemos?
# 24 días de vacaciones para que desconectes: 🏖️Disfruta de un merecido descanso con 24 días hábiles de vacaciones, para que disfrutes de tiempo de calidad!
# Contrato indefinido: 📄Contrato indefinido, brindándote seguridad y confianza en tu futuro profesional.
# Jornada intensiva todos los viernes y el mes de agosto: 🗓️¡Dale la bienvenida al fin de semana antes!Disfruta de jornadas intensivas los viernes y durante todo el mes de agosto para optimizar tu tiempo libre y equilibrar tu vida laboral."
# Retribución flexible: 💼Te ofrecemos una retribución a la carta pudiendo elegir diferentes productos tales como seguro de salud, tickets de comida, transporte, guardería, plataformas de bienestar (WellHub), etc..
# Metodología SmartWorking: 🌐Nos adaptamos a tu estilo de vida con nuestra metodología SmartWorking, que fomenta la flexibilidad y el teletrabajo, permitiéndote alcanzar un equilibrio entre tu carrera y tus compromisos personales.
# Oficinas Wellbeing: 🎾☕En nuestra sede de la Agencia West, contamos con instalaciones de bienestar de las que podrás disfrutar: gimnasio equipado, pista de pádel, rocódromo, clases individuales… Además, disponemos de Coffee Corner con café de especialidad para que puedas relajarte y disfrutar de tu pausa.
# IT&Engineering Academy: 🎓Sigue creciendo con nosotros a través de nuestra IT&Engineering Academy, el campus de formación que SII Group Spain pone a tu disposición para que puedas seguir desarrollando nuevas competencias (Hard y Soft Skills), impulsando tu crecimiento profesional y personal.Además contamos con licencias de Coursera, formación AdHoc e idiomas. 📚
# Oportunidad de aprender de grandes profesionales: 👨 🏫Aprovecha la oportunidad de aprender de los mejores. Nuestros programas de coaching y mentoring te brindan la guía y el apoyo necesarios para alcanzar tu máximo potencial.Tenemos Convenios con distintas Asociaciones y Colegios de Ingenieros, brindándote laposibilidad de acceder a formaciones y normativa específica. 📝
# Proyección de futuro y estabilidad: 🚀Diseña tu propio camino hacia el éxito con nuestro plan de carrera personalizado, que te ofrece proyección de futuro y estabilidad a largo plazo en un ambiente de trabajo colaborativo y motivador.
# Movilidad geográfica: 🌍Explora nuevas oportunidades y experiencias internacionales con nuestra opción de movilidad geográfica, permitiéndote expandir tus horizontes tanto profesional como personalmente.Eventos de empresa y networking: 🤝
# Forma parte de una comunidad cercana y vibrante.Desde after-works hasta cenas y eventos exclusivos, te ofrecemos la oportunidad de conectar y disfrutar del mejor ambiente laboral. Únete a nuestras fiestas trimestrales. 🎉
# Programa de referenciados: 📣Deseamos atraer a los profesionales más destacados y, para lograrlo, te incentivamos a que nos refieras a aquellos talentos excepcionales que conozcas.
# Plan de rebranding: 🔄Forma parte de nuestros embajadores de marca en redes sociales, contribuyendo a la estrategia de rebranding de la empresa, así como optando a distintos premios.
# Great Place to Work: 😊Únete a un equipo donde se valora tu bienestar y se --> No translation was found using the current translator. Try another translator?
# Processed 3100 records
# Processed 3200 records
# Processed 3300 records
# Processed 3400 records
# Processed 3500 records
# Processed 3600 records
# Processed 3700 records
# Processed 3800 records
# Processed 3900 records
# Processed 4000 records
# Translation error: 🌎 ADEO, QUI SOMMES-NOUS ?
#
# ADEO est une communauté d’entreprises (Leroy Merlin, Weldom, Bricoman…) de 110 000 leaders avec une ambition commune : être utile aux habitants du monde.
#
# ADEO Services est une des entités d’ADEO dont le rôle est d’accompagner nos différentes entreprises dans le monde, fournissant les produits IT et compétences nécessaires à leur digitalisation.
#
# 🌟 Dans un contexte de transformation digitale, notre défi est de construire la plateforme mondiale de l’habitat. Nos équipes IT et Data développent des écosystèmes digitaux utiles et modulaires, collaborant étroitement avec les différents métiers pour proposer des solutions adaptées aux besoins des clients, et délivrer des produits de manière plus agile et efficace.
#
# Notre culture repose sur l'innovation, la confiance et la responsabilité, favorisant une agilité collective essentielle à notre ambition digitale.
#
# 🌟 LE CONTEXTE
#
# Rattaché au Head of Cybersecurity de la plateforme Customer & Commerce Digital Platform, nous recherchons notre futur Security Engineer / DevSecOps (F/H)
#
# Véritable chef d’orchestre cybersécurité, vous jouez un rôle prépondérant dans la Sécurisation de la plateforme et l’accompagnement des équipes. Plusieurs centaines de produits digitaux en lien avec le Commerce et la gestion des Clients d'Adeo ... nous développons le "coeur du réacteur" !
#
# Customer, Commerce & Supply Chain Digital Platform ... environ 1200 personnes, plusieurs centaines de produits digitaux en lien avec le Commerce, la Gestion des Clients et la Supply Chain d'Adeo ... nous développons le "coeur du réacteur" !
#
#  Plusieurs centaines de développeurs Développement en mode agile Plusieurs livraisons par jour Environnement international
#
# 🎯 VOTRE MISSION
#
# Objectif principale de la mission ... sachant que votre mission aura aussi la dimension que vous lui donnerez ☺️ !
#
# Votre Mission Consistera à Accompagner En Proximité Les Équipes Produits (product Leader, Tech Lead, Développeur, Ops...) Dans La Mise En Œuvre Opérationnelle De La Cybersécurité. Les Objectifs De Votre Mission Évoluent Régulièrement, Et Dans Ce Contexte, Vous Serez Amené à
#
# Grâce à votre action, les équipes produits deviennent rapidement "autonome"
#
#  Dans l'implémentation by design de la sécurité dans les phases de conception, développement, intégration / déploiement continu (build) Dans le maintien permanent d'un haut de niveau de sécurité de leur produit (run) Concrètement aujourd'hui ... car nos missions évoluent et nécessitent de s'adapter régulièrement ... vous accompagnez les équipes produits sur les thématiques suivantes : Evaluation des aspects sécurité techniques dans les RFP Evaluation des risques cybersécurité techniques Implémentation des basiques de sécurité techniques Mise en place des scans sécurité Réalisation de pentests Corrections des vulnérabilités détectées lors des scans sécurité, pentests, CVE, 0-day ... Sécurisation des APIs et des expositions internet Mise en place des actions garantissant la cyber résilience
#
# Animation et coordination des opérations de Bug Bounty
#
# Définition, mise en oeuvre et optimisation des alertes SOC
#
# Définition et exploitation de dashboard sécurité pertinents permettant de mesurer, analyser, prioriser, agir, anticiper
#
# Organisation des campagnes d'évaluation du niveau de connaissances cybersécurité des développeurs + plans de progrès associés
#
# Formation et sensibilisation des développeurs
#
# Contribution active à la communauté cyber internationale Adeo
#
# 🥇 VOTRE PROFIL
#
# Vous êtes diplômé(e) d'une école d'ingénieurs, ou d'une université, avec une spécialisation cybersécurité
#
# Vous avez une première expérience de 3-4 ans minimum réussie en tant qu'expert technique DevSecOps
#
# Vous avez déjà développé
#
# Vous maîtrisez les environnements techniques suivants : GCP, Containerisation, Kubernetes, micro-services, API, iOS / Androïd, BDD Aiven, MongoDB, OWASP, Github Advanced Security, Tenable, JFROG, Image distroless, Trivy, Java, Python, Node.js ...
#
# Vous êtes connu et reconnu par vos interlocuteurs comme un véritable expert technique DevSecOps
#
# Vous maîtriser l'anglais à l'écrit et à l'oral
#
# Soft Skills
#
#  Vous êtes passionné, ouvert, bienveillant, flexible intellectuellement, positif Vous êtes curieux Vous êtes pédagogue; vous savez transmettre vos idées à l'écrit comme à l'oral Vous aimez travailler en équipe, et aussi en proximité avec vos interlocuteurs Vous êtes courageux, persévérant et avez le sens de la performance Vous êtes organisés et pouvez gérer de nombreuses tâches en parallèle Vous savez argumenter, écouter, adapter votre discours à vos interlocuteurs, convaincre Vous vous comportez en leader dans ce que vous faites
#
# 🎁 Ce que ADEO vous propose ?
#
#  Une politique de télétravail flexible Des primes de progrès et un actionnariat d’entreprise Des primes de cooptation dans le cadre des recrutements Des locaux en flex office dans une ambiance start up Une offre de restauration complète et équilibrée à tarif abordable Des services : coiffeur, --> No translation was found using the current translator. Try another translator?
# Processed 4100 records
# Processed 4200 records
# Processed 4300 records
# Processed 4400 records
# Processed 4500 records
# Processed 4600 records
# Processed 4700 records
# Processed 4800 records
# Processed 4900 records
# Processed 5000 records
# Processed 5100 records
# Processed 5200 records
# Processed 5300 records
# Processed 5400 records
# Translation error: Request exception can happen due to an api connection error. Please check your connection and try again
# Processed 5500 records
# Processed 5600 records
# Processed 5700 records
# Processed 5800 records
# Processed 5900 records
# Translation error: Choisir Capgemini, c'est choisir une entreprise où vous serez en mesure de façonner votre carrièreselon vos aspira􀆟ons, où vous serez soutenu et inspiré par unecommunauté d’experts dans le monde en􀆟er, où vous pourrez réécrire votre futur. Rejoignez-nouspour redéfinir les limites de ce qui est possible, contribuer à libérerla valeur de la technologie pour les plus grandes organisa􀆟ons et par􀆟cipez à la construc􀆟on d’unmonde plus durable et inclusif.Get The Future You Want | www.capgemini.com
# Mission : Chez Capgemini Group Cybersecurity, nous protégeons les actifs numériques et l'infrastructure du Groupe contre les menaces et les vulnérabilités. L'équipe Red Team & Offensive Security joue un rôle central en menant des simulations d'attaques réelles pour identifier les failles de sécurité et renforcer la résilience globale. En rejoignant notre équipe, vous participerez activement à la cybersécurité offensive et à la collaboration avec les équipes Blue Team et SOC pour tester et améliorer les contrôles de surveillance de la sécurité.En tant que Pentester Offensive Security Analyst – Red Team, vous serez responsable de la réalisation de tests d'intrusion avancés, de la conduite d'exercices Red Team et de la recherche de nouvelles techniques d'attaque. Vous jouerez un rôle clé en contribuant à l’amélioration des systèmes de défense de Capgemini, en simulant des cyberattaques réalistes et en testant la résilience des infrastructures, des applications web et des environnements cloud.
# ...
# Il candidato ideale deve conoscere le pratiche di Secure Coding, la gestione delle vulnerabilità e i framework di sicurezza, implementando misure di sicurezza durante tutto il ciclo di vita del software.
# 👁️ OCCHIO: È richiesta ottima conoscenza della lingua inglese, poiché il candidato ideale verrà inserito in un team internazionale!
# 🔝COMPLETANO IL PROFILO:
# - Spiccata attitudine al lavoro in team e propensione alla leadership- Spiccate doti relazionali- Elevata capacità di problem solving
# 📍Sede di lavoro: Torino, Modena, Napoli, Roma, Bari.
# ➡️ Qual è il prossimo step?
# Potresti essere contattato dal nostro team HR per approfondire le tue competenze e i tuoi interessi, in modo da considerare il tuo profilo per ogni posizione aperta in linea con il tuo profilo.
# 🔎Cosa offriamo?
# · Contratto full time, tempo indeterminato CCNL Metalmeccanico· Modalità di lavoro flessibile· Ticket Restaurant del valore di EURO 8.· Assicurazione Sanitaria e Welfare previsti da CCNL di Riferimento
# 🟠🔵Perché scegliere Teoresi?
# Teoresi è una realtà nata a Torino e cresciuta fino a diventare oggi un gruppo internazionale, che si propone ovunque si respiri innovazione. Perseguiamo l’aggiornamento continuo rispetto all’evoluzione tecnologica, collaborando con aziende Leader in diversi settori di mercato e realizzando soluzioni “chiavi in mano” presso i nostri laboratori.
# Lavoriamo mantenendo al centro le persone e la sostenibilità ambientale.Crediamo nel risultato generato dall’unione del talento creativo e la solida preparazione dei nostri collaboratori, strumenti vincenti per rendere la tecnologia un ponte verso il cambiamento e proporre soluzioni che siano “un passo avanti”, anticipando bisogni e tendenze future a beneficio della vita umana.
# 🫂 Amiamo le occasioni di incontro, per questo supportiamo eventi in grado di generare nuove opportunità, non solo di business, ma anche di scambio culturale, intergenerazionale, internazionale, riducendo qualsiasi distanza. Scopri di più su tutti gli eventi Teoresi, che ogni anno ci portano a conoscerci e ritrovarci! https://www.teoresigroup.com/it/connect/experiences/
# 🌳 Nel welcome kit troverai una borraccia in acciaio brandizzata realizzata da 24 Bottles, nata dall’idea di sostituire i distributori automatici di bottiglie di plastica con erogatori gratuiti di acqua potabile in tutte le nostre sedi (clicca qui per saperne di più sulle nostre iniziative in tema di sostenibilità https://www.teoresigroup.com/it/about/sustainability/ ).
# L’offerta è rivolta ad entrambi i sessi in ottemperanza al --> No translation was found using the current translator. Try another translator?
# Processed 11000 records
# Processed 11100 records
# Processed 11200 records
# Processed 11300 records
# Processed 11400 records
# Processed 11500 records
# Processed 11600 records
# Processed 11700 records
# Processed 11800 records
# Processed 11900 records
# Processed 12000 records
# Processed 12100 records
# Processed 12200 records
# Translation error: zh-cn --> No support for the provided language.
# Please select on of the supported languages:
# {'afrikaans': 'af', 'albanian': 'sq', 'amharic': 'am', 'arabic': 'ar', 'armenian': 'hy', 'assamese': 'as', 'aymara': 'ay', 'azerbaijani': 'az', 'bambara': 'bm', 'basque': 'eu', 'belarusian': 'be', 'bengali': 'bn', 'bhojpuri': 'bho', 'bosnian': 'bs', 'bulgarian': 'bg', 'catalan': 'ca', 'cebuano': 'ceb', 'chichewa': 'ny', 'chinese (simplified)': 'zh-CN', 'chinese (traditional)': 'zh-TW', 'corsican': 'co', 'croatian': 'hr', 'czech': 'cs', 'danish': 'da', 'dhivehi': 'dv', 'dogri': 'doi', 'dutch': 'nl', 'english': 'en', 'esperanto': 'eo', 'estonian': 'et', 'ewe': 'ee', 'filipino': 'tl', 'finnish': 'fi', 'french': 'fr', 'frisian': 'fy', 'galician': 'gl', 'georgian': 'ka', 'german': 'de', 'greek': 'el', 'guarani': 'gn', 'gujarati': 'gu', 'haitian creole': 'ht', 'hausa': 'ha', 'hawaiian': 'haw', 'hebrew': 'iw', 'hindi': 'hi', 'hmong': 'hmn', 'hungarian': 'hu', 'icelandic': 'is', 'igbo': 'ig', 'ilocano': 'ilo', 'indonesian': 'id', 'irish': 'ga', 'italian': 'it', 'japanese': 'ja', 'javanese': 'jw', 'kannada': 'kn', 'kazakh': 'kk', 'khmer': 'km', 'kinyarwanda': 'rw', 'konkani': 'gom', 'korean': 'ko', 'krio': 'kri', 'kurdish (kurmanji)': 'ku', 'kurdish (sorani)': 'ckb', 'kyrgyz': 'ky', 'lao': 'lo', 'latin': 'la', 'latvian': 'lv', 'lingala': 'ln', 'lithuanian': 'lt', 'luganda': 'lg', 'luxembourgish': 'lb', 'macedonian': 'mk', 'maithili': 'mai', 'malagasy': 'mg', 'malay': 'ms', 'malayalam': 'ml', 'maltese': 'mt', 'maori': 'mi', 'marathi': 'mr', 'meiteilon (manipuri)': 'mni-Mtei', 'mizo': 'lus', 'mongolian': 'mn', 'myanmar': 'my', 'nepali': 'ne', 'norwegian': 'no', 'odia (oriya)': 'or', 'oromo': 'om', 'pashto': 'ps', 'persian': 'fa', 'polish': 'pl', 'portuguese': 'pt', 'punjabi': 'pa', 'quechua': 'qu', 'romanian': 'ro', 'russian': 'ru', 'samoan': 'sm', 'sanskrit': 'sa', 'scots gaelic': 'gd', 'sepedi': 'nso', 'serbian': 'sr', 'sesotho': 'st', 'shona': 'sn', 'sindhi': 'sd', 'sinhala': 'si', 'slovak': 'sk', 'slovenian': 'sl', 'somali': 'so', 'spanish': 'es', 'sundanese': 'su', 'swahili': 'sw', 'swedish': 'sv', 'tajik': 'tg', 'tamil': 'ta', 'tatar': 'tt', 'telugu': 'te', 'thai': 'th', 'tigrinya': 'ti', 'tsonga': 'ts', 'turkish': 'tr', 'turkmen': 'tk', 'twi': 'ak', 'ukrainian': 'uk', 'urdu': 'ur', 'uyghur': 'ug', 'uzbek': 'uz', 'vietnamese': 'vi', 'welsh': 'cy', 'xhosa': 'xh', 'yiddish': 'yi', 'yoruba': 'yo', 'zulu': 'zu'}
# Processed 12300 records
# Processed 12400 records
# Processed 12500 records
# Translation error: ¡Únete al equipo de SII Group Spain y ayúdanos a impulsar la transformación digital e innovación!
# 🔐 Buscamos un/a Application Security Consultant (AppSec Specialist) 🔐¿Quieres impulsar tu carrera en ciberseguridad de aplicaciones dentro de un entorno internacional exigente y altamente tecnológico? 🚀 Estamos buscando un/a especialista en AppSec / Seguridad de Aplicaciones que aporte experiencia en arquitectura de seguridad, análisis de riesgos y pruebas de seguridad para proyectos de desarrollo y operación de aplicaciones.
# 📌 ResponsabilidadesIntegrar la seguridad de extremo a extremo en proyectos de desarrollo.Coordinar con distintos equipos de seguridad y de aplicaciones.Analizar riesgos de aplicaciones y recomendar soluciones de seguridad.Asegurar el cumplimiento de requisitos de seguridad antes del paso a producción.Apoyar en la ejecución y análisis de pruebas de seguridad (Pentest, SAST, DAST, etc.).Contribuir en proyectos transversales de seguridad: políticas, modelos de arquitectura, DevSecOps, etc.
# 🎯 RequisitosExperiencia en seguridad de aplicaciones y/o arquitectura de seguridad IT.Conocimiento de pruebas de seguridad y metodologías de análisis de riesgos.Familiaridad con múltiples lenguajes (Java, JavaScript, PHP, etc.) y arquitecturas (N-tier, microservicios, mobile, blockchain).Experiencia con entornos cloud e híbridos.Inglés fluido (entorno de trabajo internacional).
# 💼 OfrecemosProyecto internacional en ciberseguridad con alto impacto.Entorno multicultural y dinámico.Oportunidad de trabajar con tecnologías y arquitecturas diversas.Modalidad híbrida de trabajo.
# 👉 Si te apasiona la seguridad de aplicaciones y quieres asumir un rol clave en la protección de sistemas críticos, ¡esta es tu oportunidad!
# ¿Quiénes somos?
# En SII Group, con más de 16.000 profesionales en 20 países, ofrecemos servicios de IT, Ingeniería y Consultoría que impulsan la transformación digital en múltiples industrias. Nos guiamos por los pilares estratégicos: Growth, People & ESG, manteniendo una cultura de confianza y excelencia reconocida por nuestro equipo con la certificación Great Place to Work.
# Let’s Tech Together
# Let’s Tech Together es nuestra promesa y filosofía. Nos atrevemos a innovar, a tomar la iniciativa y a construir un futuro tecnológico juntos. Valoramos la autonomía, la experimentación y la inclusión, creando un entorno donde cada idea cuenta y donde cada miembro del equipo puede crecer profesional y personalmente
# ¿Qué te ofrecemos?
# 24 días de vacaciones para que desconectes: 🏖️Disfruta de un merecido descanso con 24 días hábiles de vacaciones, para que disfrutes de tiempo de calidad!
# Contrato indefinido: 📄Contrato indefinido, brindándote seguridad y confianza en tu futuro profesional.
# Jornada intensiva todos los viernes y el mes de agosto: 🗓️¡Dale la bienvenida al fin de semana antes!Disfruta de jornadas intensivas los viernes y durante todo el mes de agosto para optimizar tu tiempo libre y equilibrar tu vida laboral."
# Retribución flexible: 💼Te ofrecemos una retribución a la carta pudiendo elegir diferentes productos tales como seguro de salud, tickets de comida, transporte, guardería, plataformas de bienestar (WellHub), etc..
# Metodología SmartWorking: 🌐Nos adaptamos a tu estilo de vida con nuestra metodología SmartWorking, que fomenta la flexibilidad y el teletrabajo, permitiéndote alcanzar un equilibrio entre tu carrera y tus compromisos personales.
# Oficinas Wellbeing: 🎾☕En nuestra sede de la Agencia West, contamos con instalaciones de bienestar de las que podrás disfrutar: gimnasio equipado, pista de pádel, rocódromo, clases individuales… Además, disponemos de Coffee Corner con café de especialidad para que puedas relajarte y disfrutar de tu pausa.
# IT&Engineering Academy: 🎓Sigue creciendo con nosotros a través de nuestra IT&Engineering Academy, el campus de formación que SII Group Spain pone a tu disposición para que puedas seguir desarrollando nuevas competencias (Hard y Soft Skills), impulsando tu crecimiento profesional y personal.Además contamos con licencias de Coursera, formación AdHoc e idiomas. 📚
# Oportunidad de aprender de grandes profesionales: 👨 🏫Aprovecha la oportunidad de aprender de los mejores. Nuestros programas de coaching y mentoring te brindan la guía y el apoyo necesarios para alcanzar tu máximo potencial.Tenemos Convenios con distintas Asociaciones y Colegios de Ingenieros, brindándote laposibilidad de acceder a formaciones y normativa específica. 📝
# Proyección de futuro y estabilidad: 🚀Diseña tu propio camino hacia el éxito con nuestro plan de carrera personalizado, que te ofrece proyección de futuro y estabilidad a largo plazo en un ambiente de trabajo colaborativo y motivador.
# Movilidad geográfica: 🌍Explora nuevas oportunidades y experiencias internacionales con nuestra opción de movilidad geográfica, permitiéndote expandir tus horizontes tanto profesional como personalmente.Eventos de empresa y networking: 🤝
# Forma parte de una comunidad cercana y vibrante.Desde after-works hasta --> No translation was found using the current translator. Try another translator?
# Processed 12600 records
# Processed 12700 records
# Processed 12800 records
# Processed 12900 records
# Processed 13000 records
# Processed 13100 records
# Processed 13200 records
# Processed 13300 records
# Processed 13400 records
# Processed 13500 records
# Processed 13600 records
# Processed 13700 records
# Processed 13800 records
# Processed 13900 records
# Processed 14000 records
# Processed 14100 records
# Processed 14200 records
# Processed 14300 records
# Processed 14400 records
# Processed 100 records
# Processed 200 records
# Processed 300 records
# Processed 400 records
# Processed 500 records
# Processed 600 records
# Processed 700 records
# Processed 800 records
# Processed 900 records
# Processed 1000 records
# Translation error: ION · Parma, Emilia-Romagna, Italy (Hybrid) --> No translation was found using the current translator. Try another translator?
# Processed 1100 records
# Processed 1200 records
# Processed 1300 records
# Processed 1400 records
# Processed 1500 records
# Processed 1600 records
# Processed 1700 records
# Processed 1800 records
# Processed 1900 records
# Processed 2000 records
# Processed 2100 records
# Processed 2200 records
# Processed 2300 records
# Processed 2400 records
# Processed 2500 records
# Processed 2600 records
# Processed 2700 records
# Processed 2800 records
# Processed 2900 records
# Processed 3000 records
# Processed 3100 records
# Translation error: Relativity · Wrocław, Dolnośląskie, Poland (Remote) --> No translation was found using the current translator. Try another translator?
# Processed 3200 records
# Processed 3300 records
# Processed 3400 records
# Processed 3500 records
# Processed 3600 records
# Processed 3700 records
# Processed 3800 records
# Processed 3900 records
# Processed 4000 records
# Processed 4100 records
# Processed 4200 records
# Processed 4300 records
# Processed 4400 records
# Processed 4500 records
# Processed 4600 records
# Processed 4700 records
# Processed 4800 records
# Processed 4900 records
# Processed 5000 records
# Processed 5100 records
# Processed 5200 records
# Processed 5300 records
# Processed 5400 records
# Processed 5500 records
# Processed 5600 records
# Translation error: Insta · Tampere, Pirkanmaa, Finland (Hybrid) --> No translation was found using the current translator. Try another translator?
# Translation error: Alstom · Stockholm, Stockholm County, Sweden (Hybrid) --> No translation was found using the current translator. Try another translator?
# Processed 5700 records
# Processed 5800 records
# Translation error: SMP Automotive Global · Stuttgart, Baden-Württemberg, Germany (On-site) --> No translation was found using the current translator. Try another translator?
# Processed 5900 records
# Processed 6000 records
# Processed 6100 records
# Processed 6200 records
# Translation error: Juni · Stockholm, Stockholm County, Sweden (Hybrid) --> No translation was found using the current translator. Try another translator?
# Translation error: Föreningen HR- Akademikerna vid Stockholms universitet · Stockholm, Stockholm County, Sweden (On-site) --> No translation was found using the current translator. Try another translator?
# Processed 6300 records
# Processed 6400 records
# Processed 6500 records
# Processed 6600 records
# Processed 6700 records
# Processed 6800 records
# Translation error: SAVR · Stockholm, Stockholm County, Sweden (On-site) --> No translation was found using the current translator. Try another translator?
# Processed 6900 records
# Processed 7000 records
# Processed 7100 records
# Processed 7200 records
# Processed 7300 records
# Processed 7400 records
# Processed 7500 records
# Processed 7600 records
# Processed 7700 records
# Processed 7800 records
# Processed 7900 records
# Processed 8000 records
# Processed 8100 records
# Processed 8200 records
# Processed 8300 records
# Processed 8400 records
# Processed 8500 records
# Processed 8600 records
# Processed 8700 records
# Processed 8800 records
# Processed 8900 records
# Processed 9000 records
# Processed 9100 records
# Processed 9200 records
# Translation error: Kincy · Marseille, Provence-Alpes-Côte d'Azur, France (Hybrid) --> No translation was found using the current translator. Try another translator?
# Translation error: Data Visualization Society · Zürich Metropolitan Area (Remote) --> No translation was found using the current translator. Try another translator?
# Processed 9300 records
# Processed 9400 records
# Processed 9500 records
# Processed 9600 records
# Processed 9700 records
# Processed 9800 records
# Processed 9900 records
# Processed 10000 records
# Processed 10100 records
# Processed 10200 records
# Processed 10300 records
# Processed 10400 records
# Processed 10500 records
# Processed 10600 records
# Processed 10700 records
# Processed 10800 records
# Processed 10900 records
# Processed 11000 records
# Processed 11100 records
# Processed 11200 records
# Processed 11300 records
# Processed 11400 records
# Processed 11500 records
# Processed 11600 records
# Processed 11700 records
# Processed 11800 records
# Processed 11900 records
# Processed 12000 records
# Processed 12100 records
# Processed 12200 records
# Processed 12300 records
# Processed 12400 records
# Processed 12500 records
# Processed 12600 records
# Processed 12700 records
# Processed 12800 records
# Processed 12900 records
# Processed 13000 records
# Processed 13100 records
# Processed 13200 records
# Processed 13300 records
# Processed 13400 records
# Processed 13500 records
# Processed 13600 records
# Processed 13700 records
# Processed 13800 records
# Processed 13900 records
# Processed 14000 records
# Processed 14100 records
# Processed 14200 records
# Processed 14300 records
# Processed 14400 records
